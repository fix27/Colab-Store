# %% [markdown]
# <a href="https://colab.research.google.com/github/fix27/Colab-Store/blob/main/AutoTicket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program AutoTicket;
countLenStr = 32
kombcount= [0, 1, 2, 6, 24, 120]
t5Byte = [0,0,0,0,0]
t5 = [0,0,0,0,0]
t6 = [0,0,0,0,0,0]
t7 = [0,0,0,0,0,0,0]
initcomb = True
nums = t7.copy()
iSign = t6.copy()
#var
#  counttrue: comp;
#  nums: array [1 .. 6] of longint;
#  LenStr: array [1 .. 6] of byte;
#  calcNumber: array [1 .. 6] of single;
#  iSign, calcOrder, calcSign: t5Byte;
#  LenStrAll: array [1 .. countLenStr, 1 .. 6] of byte;
#  kombAll: array [1 .. 5, 1 .. 120] of t5Byte;
#  { kombAllIndex: array [1 .. 5, 1 .. 120, 1 .. 5] of byte; }
#  rezbol, fixLenZero, exzero: boolean;
#  numStr,tmps: String;
#  CountMathOper, iCalcOrder, iMathOper, firstSign, countmoveel: byte;
#  gi: longint;
#  i, i1, iLenStr: Integer;

if initcomb :
#var
#  mtmp: array [1 .. 5] of byte;
#  flag1: boolean;
#  i11, i12, comb, iLenStr0: byte;
#begin
  # 0
  kombAll=[]
  kombAll.append(0)
  # 1
  a3 = [1]
  a2 = []
  a2.append(a3)
  kombAll.append(a2)
  # 2
  a2 = []
  a3 = [1,2]
  a2.append(a3)
  a4 = [2,1]
  a2.append(a4)
  kombAll.append(a2)
  

 # kombAll[1, 1, 1] := 1;
 # { kombAllIndex[1, 1, 1] := 1; }
  # 3
  mtmp=t5.copy()
  a2=[]
  comb = 0
  mtmp[0] = 0
  while mtmp[0] < 3 :
    mtmp[0] = mtmp[0] + 1;
    mtmp[1] = 0
    while mtmp[1] < 3 :
      mtmp[1] = mtmp[1] + 1;
      mtmp[2] = 0
      while mtmp[2] < 3 :
        mtmp[2] = mtmp[2] + 1;
        flag1 = True
        for i11 in range(2)  :
          for i12 in range(i11 + 1,3)  :
            if mtmp[i11] == mtmp[i12] :
              flag1 = False
        if flag1 :
          comb=comb+1
          #for i11 := 1 to 3 do
          a2.append(mtmp.copy())
            
  kombAll.append(a2)
  #4
  a2=[]
  comb = 0
  mtmp=t5.copy()
  mtmp[0] = 0
  while mtmp[0] < 4 :
    mtmp[0] = mtmp[0] + 1
    mtmp[1] = 0
    while mtmp[1] < 4 :
      mtmp[1] = mtmp[1] + 1
      mtmp[2] = 0
      while mtmp[2] < 4 :
        mtmp[2] = mtmp[2] + 1
        mtmp[3] = 0
        while mtmp[3] < 4 :
         mtmp[3] = mtmp[3] + 1
         flag1 = True;
         for i11 in range(3) :
           for i12 in range(i11 + 1,4)  :
              if mtmp[i11] == mtmp[i12] :
                flag1 = False
         if flag1 :
            comb=comb+1
            a2.append(mtmp.copy())
            
  kombAll.append(a2)           


#5
  a2=[]
  comb = 0
  mtmp=t5.copy()
  mtmp[0] = 0
  while mtmp[0] < 5 :
    mtmp[0] = mtmp[0] + 1
    mtmp[1] = 0
    while mtmp[1] < 5 :
      mtmp[1] = mtmp[1] + 1
      mtmp[2] = 0
      while mtmp[2] < 5 :
        mtmp[2] = mtmp[2] + 1
        mtmp[3] = 0
        while mtmp[3] < 5 :
         mtmp[3] = mtmp[3] + 1
         mtmp[4] = 0
         while mtmp[4] < 5 :
            mtmp[4] = mtmp[4] + 1
            flag1 = True;
            for i11 in range(4) :
             for i12 in range(i11 + 1,5)  :
               if mtmp[i11] == mtmp[i12] :
                 flag1 = False
            if flag1 :
              comb=comb+1
              a2.append(mtmp.copy())
            
  kombAll.append(a2)           

  LenStrAll = []
  LenStr = t7.copy()
  iLenStr0 = 0
  LenStr[0] = 0
  LenStr[6] = 0
  while LenStr[6] < 2:
    LenStr[5] = 0;
    while LenStr[5] < 3:
      LenStr[4] = 0
      while LenStr[4] < 4:
        LenStr[3] = 0;
        while LenStr[3] < 5:
          LenStr[2] = 0;
          while LenStr[2] < 6:
            LenStr[1] = 1;
            while LenStr[1] < 7:
              if ((LenStr[1] + LenStr[2] + LenStr[3] + LenStr[4] + LenStr[5] +
                LenStr[6]) == 6) :
                fixLenZero = True
                for i11 in range(2,6) :
                  if (LenStr[i11] == 0) and (LenStr[i11 + 1] > 0) :
                    fixLenZero = False
                if fixLenZero :
                
                  iLenStr0 = iLenStr0 + 1
                  #LenStrAll[iLenStr0]
                  LenStrAll.append(LenStr.copy());
                
                

              LenStr[1] = LenStr[1] + 1

            LenStr[2] = LenStr[2] + 1

          LenStr[3] = LenStr[3] + 1

        LenStr[4] = LenStr[4] + 1

      LenStr[5] = LenStr[5] + 1

    LenStr[6] = LenStr[6] + 1

  if iLenStr0 != countLenStr :

    print( 'error countLenStr');
    print( countLenStr);
    print( iLenStr0);

#print(kombAll[5][119][4])
with open('output.txt', 'w') as outfile:

 counttrue= 0
 for gi in range(999999) :
  
    rezbol = False
    tmps=''
    numStr = str(gi)
    while len(numStr) < 6 :
      numStr = '0' + numStr;
    for iLenStr in range(countLenStr) : 
      for i in range(1,7) :
        nums[i] = 1000000;
      i = 0
      CountMathOper = 0

      while i < 6:
        CountMathOper=CountMathOper+1
        if LenStrAll[iLenStr][ CountMathOper] > 0 :
          nums[CountMathOper] = int('0'+numStr[i:i+int(LenStrAll[iLenStr][ CountMathOper])])
         # print(nums[CountMathOper],i,LenStrAll[iLenStr][ CountMathOper])
        i = i + int(LenStrAll[iLenStr][ CountMathOper])
      
      for firstSign in range( 1,3 ) :
     
        nums[1] = abs(nums[1]) if firstSign == 1 else (abs(nums[1]) * (-1))
        #  nums[1] = abs(nums[1])
        #else :
        #  nums[1] = abs(nums[1]) * (-1)
        iSign[1] = 1
        while not (rezbol or (iSign[1] > 1 + (5 *  ( 1 if CountMathOper > 1 else 0) ))) :
          iSign[2] = 1
          while not (rezbol or (iSign[2] > 1 + (5 * ( 1 if CountMathOper > 2 else 0) ))) :
            iSign[3] = 1
            while not (rezbol or (iSign[3] > 1 + (5 * ( 1 if CountMathOper > 3 else 0)))) :
              iSign[4] = 1
              while not (rezbol or (iSign[4] > 1 + (5 * ( 1 if CountMathOper > 4 else 0)))) :
                iSign[5] = 1
                while not (rezbol or (iSign[5] > 1 + (5 * ( 1 if CountMathOper > 5 else 0)))) :
                  calcNumber=t7.copy()

                  for i in range(kombcount[CountMathOper - 1]) :
                  
                    exzero = False
                    #for i1 in range(1,CountMathOper+1) :
                    #  calcNumber[i1] = nums[i1]
                    calcNumber = nums.copy()
                    calcSign = iSign.copy()
                    calcOrder = kombAll[CountMathOper - 1][ i].copy()

                    for iMathOper in range(1, CountMathOper ) :
       
                      #iCalcOrder = 0
                      
                      #while iCalcOrder<len(calcOrder) and calcOrder[iCalcOrder] != iMathOper :
                      #  iCalcOrder=iCalcOrder+1
                      #iCalcOrder=iCalcOrder+1

                      iCalcOrder = calcOrder.index(iMathOper)+1
                      if (calcNumber[(iCalcOrder + 1)] == 0) and (calcSign[iCalcOrder] in [4, 6]) :
                        exzero = True
                      if exzero :
                        break;
                      if calcSign[iCalcOrder] == 1 :
                          calcNumber[iCalcOrder] = calcNumber[iCalcOrder] + calcNumber[(iCalcOrder + 1)]
                      elif calcSign[iCalcOrder] == 2 :
                          calcNumber[iCalcOrder] = calcNumber[iCalcOrder] -  calcNumber[(iCalcOrder + 1)]
                      elif calcSign[iCalcOrder] == 3 :
                          calcNumber[iCalcOrder] = calcNumber[iCalcOrder] *  calcNumber[(iCalcOrder + 1)]
                      elif calcSign[iCalcOrder] == 4 :
                          calcNumber[iCalcOrder] = calcNumber[iCalcOrder] / calcNumber[(iCalcOrder + 1)]
                      elif calcSign[iCalcOrder] == 5 :
                          calcNumber[iCalcOrder] = calcNumber[iCalcOrder] * (-1 * calcNumber[(iCalcOrder + 1)])
                      elif calcSign[iCalcOrder] == 6 :
                          calcNumber[iCalcOrder] = calcNumber[iCalcOrder] / (-1 * calcNumber[(iCalcOrder + 1)])
                    
                     # countmoveel = CountMathOper - iMathOper - iCalcOrder
                      #calcNumber[iCalcOrder + 1]=calcNumber[iCalcOrder + 2].copy()
                      #calcSign[iCalcOrder] = calcSign[iCalcOrder + 1].copy()
                     # calcOrder[iCalcOrder] = calcOrder[iCalcOrder + 1].copy()
        
                      for i1 in range( iCalcOrder + 1 , (CountMathOper - iMathOper)+1 ):
                        
                        calcNumber[i1]    = calcNumber[i1 + 1]
                        calcSign[i1 - 1]  = calcSign[i1]
                        calcOrder[i1 - 2] = calcOrder[i1-1]
                      
                    if exzero :
                      continue
                    
                    if calcNumber[1] == 100 :
                      #print(calcNumber[1])
                      tmps = tmps + str(nums[1]) + ' '
                      for i1 in range(2 , CountMathOper +1) :
                        tmps = tmps + '(' + str(kombAll[CountMathOper - 1][ i][ i1 - 2]) + ') '
                        if iSign[(i1 - 1)] == 1 :
                            tmps = tmps + '+ '
                        elif iSign[(i1 - 1)]== 2 :
                            tmps = tmps + '- '
                        elif iSign[(i1 - 1)]== 3 :
                            tmps = tmps + '* '
                        elif iSign[(i1 - 1)]== 4 :
                            tmps = tmps + '/ '
                        elif iSign[(i1 - 1)]== 5 :
                            tmps = tmps + '* -'
                        elif iSign[(i1 - 1)]== 6 :
                            tmps = tmps + '/ -'
                        
                        tmps = tmps + str(nums[i1]) + ' '
                     
                      tmps = tmps + chr(13)+chr(10)
                      rezbol = True

                    if rezbol :
                      break;

                  iSign[5] = iSign[5] + 1

                iSign[4] = iSign[4] + 1

              iSign[3] = iSign[3] + 1

            iSign[2] = iSign[2] + 1

          iSign[1] = iSign[1] + 1

        if rezbol :
          break;
    
      if rezbol :
        break;

    if rezbol :
      counttrue = counttrue + 1

    outfile.write('Ticket '+ str(gi)+ ' Rezult:'+ str(rezbol)+  ' Count true:'+ str(counttrue)+  chr(13)+chr(10)+tmps)
    print('Ticket '+ str(gi)+ ' Rezult:'+ str(rezbol)+  ' Count true:'+ str(counttrue)+  chr(13)+chr(10)+tmps)
# Out:
# Ticket 0 Rezult:False Count true:0
#
# Ticket 1 Rezult:False Count true:0
#
# Ticket 2 Rezult:False Count true:0
#
# Ticket 3 Rezult:False Count true:0
#
# Ticket 4 Rezult:False Count true:0
#
# Ticket 5 Rezult:False Count true:0
#
# Ticket 6 Rezult:False Count true:0
#
# Ticket 7 Rezult:False Count true:0
#
# Ticket 8 Rezult:False Count true:0
#
# Ticket 9 Rezult:False Count true:0
#
# Ticket 10 Rezult:False Count true:0
#
# Ticket 11 Rezult:False Count true:0
#
# Ticket 12 Rezult:False Count true:0
#
# Ticket 13 Rezult:False Count true:0
#
# Ticket 14 Rezult:False Count true:0
#
# Ticket 15 Rezult:False Count true:0
#
# Ticket 16 Rezult:False Count true:0
#
# Ticket 17 Rezult:False Count true:0
#
# Ticket 18 Rezult:False Count true:0
#
# Ticket 19 Rezult:False Count true:0
#
# Ticket 20 Rezult:False Count true:0
#
# Ticket 21 Rezult:False Count true:0
#
# Ticket 22 Rezult:False Count true:0
#
# Ticket 23 Rezult:False Count true:0
#
# Ticket 24 Rezult:False Count true:0
#
# Ticket 25 Rezult:False Count true:0
#
# Ticket 26 Rezult:False Count true:0
#
# Ticket 27 Rezult:False Count true:0
#
# Ticket 28 Rezult:False Count true:0
#
# Ticket 29 Rezult:False Count true:0
#
# Ticket 30 Rezult:False Count true:0
#
# Ticket 31 Rezult:False Count true:0
#
# Ticket 32 Rezult:False Count true:0
#
# Ticket 33 Rezult:False Count true:0
#
# Ticket 34 Rezult:False Count true:0
#
# Ticket 35 Rezult:False Count true:0
#
# Ticket 36 Rezult:False Count true:0
#
# Ticket 37 Rezult:False Count true:0
#
# Ticket 38 Rezult:False Count true:0
#
# Ticket 39 Rezult:False Count true:0
#
# Ticket 40 Rezult:False Count true:0
#
# Ticket 41 Rezult:False Count true:0
#
# Ticket 42 Rezult:False Count true:0
#
# Ticket 43 Rezult:False Count true:0
#
# Ticket 44 Rezult:False Count true:0
#
# Ticket 45 Rezult:False Count true:0
#
# Ticket 46 Rezult:False Count true:0
#
# Ticket 47 Rezult:False Count true:0
#
# Ticket 48 Rezult:False Count true:0
#
# Ticket 49 Rezult:False Count true:0
#
# Ticket 50 Rezult:False Count true:0
#
# Ticket 51 Rezult:False Count true:0
#
# Ticket 52 Rezult:False Count true:0
#
# Ticket 53 Rezult:False Count true:0
#
# Ticket 54 Rezult:False Count true:0
#
# Ticket 55 Rezult:False Count true:0
#
# Ticket 56 Rezult:False Count true:0
#
# Ticket 57 Rezult:False Count true:0
#
# Ticket 58 Rezult:False Count true:0
#
# Ticket 59 Rezult:False Count true:0
#
# Ticket 60 Rezult:False Count true:0
#
# Ticket 61 Rezult:False Count true:0
#
# Ticket 62 Rezult:False Count true:0
#
# Ticket 63 Rezult:False Count true:0
#
# Ticket 64 Rezult:False Count true:0
#
# Ticket 65 Rezult:False Count true:0
#
# Ticket 66 Rezult:False Count true:0
#
# Ticket 67 Rezult:False Count true:0
#
# Ticket 68 Rezult:False Count true:0
#
# Ticket 69 Rezult:False Count true:0
#
# Ticket 70 Rezult:False Count true:0
#
# Ticket 71 Rezult:False Count true:0
#
# Ticket 72 Rezult:False Count true:0
#
# Ticket 73 Rezult:False Count true:0
#
# Ticket 74 Rezult:False Count true:0
#
# Ticket 75 Rezult:False Count true:0
#
# Ticket 76 Rezult:False Count true:0
#
# Ticket 77 Rezult:False Count true:0
#
# Ticket 78 Rezult:False Count true:0
#
# Ticket 79 Rezult:False Count true:0
#
# Ticket 80 Rezult:False Count true:0
#
# Ticket 81 Rezult:False Count true:0
#
# Ticket 82 Rezult:False Count true:0
#
# Ticket 83 Rezult:False Count true:0
#
# Ticket 84 Rezult:False Count true:0
#
# Ticket 85 Rezult:False Count true:0
#
# Ticket 86 Rezult:False Count true:0
#
# Ticket 87 Rezult:False Count true:0
#
# Ticket 88 Rezult:False Count true:0
#
# Ticket 89 Rezult:False Count true:0
#
# Ticket 90 Rezult:False Count true:0
#
# Ticket 91 Rezult:False Count true:0
#
# Ticket 92 Rezult:False Count true:0
#
# Ticket 93 Rezult:False Count true:0
#
# Ticket 94 Rezult:False Count true:0
#
# Ticket 95 Rezult:False Count true:0
#
# Ticket 96 Rezult:False Count true:0
#
# Ticket 97 Rezult:False Count true:0
#
# Ticket 98 Rezult:False Count true:0
#
# Ticket 99 Rezult:False Count true:0
#
# Ticket 100 Rezult:True Count true:1
# 0 (1) + 100
#
# Ticket 101 Rezult:False Count true:1
#
# Ticket 102 Rezult:False Count true:1
#
# Ticket 103 Rezult:False Count true:1
#
# Ticket 104 Rezult:False Count true:1
#
# Ticket 105 Rezult:False Count true:1
#
# Ticket 106 Rezult:False Count true:1
#
# Ticket 107 Rezult:False Count true:1
#
# Ticket 108 Rezult:False Count true:1
#
# Ticket 109 Rezult:False Count true:1
#
# Ticket 110 Rezult:False Count true:1
#
# Ticket 111 Rezult:False Count true:1
#
# Ticket 112 Rezult:False Count true:1
#
# Ticket 113 Rezult:False Count true:1
#
# Ticket 114 Rezult:False Count true:1
#
# Ticket 115 Rezult:False Count true:1
#
# Ticket 116 Rezult:False Count true:1
#
# Ticket 117 Rezult:False Count true:1
#
# Ticket 118 Rezult:False Count true:1
#
# Ticket 119 Rezult:False Count true:1
#
# Ticket 120 Rezult:False Count true:1
#
# Ticket 121 Rezult:False Count true:1
#
# Ticket 122 Rezult:False Count true:1
#
# Ticket 123 Rezult:False Count true:1
#
# Ticket 124 Rezult:False Count true:1
#
# Ticket 125 Rezult:False Count true:1
#
# Ticket 126 Rezult:False Count true:1
#
# Ticket 127 Rezult:False Count true:1
#
# Ticket 128 Rezult:False Count true:1
#
# Ticket 129 Rezult:False Count true:1
#
# Ticket 130 Rezult:False Count true:1
#
# Ticket 131 Rezult:False Count true:1
#
# Ticket 132 Rezult:False Count true:1
#
# Ticket 133 Rezult:False Count true:1
#
# Ticket 134 Rezult:False Count true:1
#
# Ticket 135 Rezult:False Count true:1
#
# Ticket 136 Rezult:False Count true:1
#
# Ticket 137 Rezult:False Count true:1
#
# Ticket 138 Rezult:False Count true:1
#
# Ticket 139 Rezult:False Count true:1
#
# Ticket 140 Rezult:False Count true:1
#
# Ticket 141 Rezult:False Count true:1
#
# Ticket 142 Rezult:False Count true:1
#
# Ticket 143 Rezult:False Count true:1
#
# Ticket 144 Rezult:False Count true:1
#
# Ticket 145 Rezult:False Count true:1
#
# Ticket 146 Rezult:False Count true:1
#
# Ticket 147 Rezult:False Count true:1
#
# Ticket 148 Rezult:False Count true:1
#
# Ticket 149 Rezult:False Count true:1
#
# Ticket 150 Rezult:False Count true:1
#
# Ticket 151 Rezult:False Count true:1
#
# Ticket 152 Rezult:False Count true:1
#
# Ticket 153 Rezult:False Count true:1
#
# Ticket 154 Rezult:False Count true:1
#
# Ticket 155 Rezult:False Count true:1
#
# Ticket 156 Rezult:False Count true:1
#
# Ticket 157 Rezult:False Count true:1
#
# Ticket 158 Rezult:False Count true:1
#
# Ticket 159 Rezult:False Count true:1
#
# Ticket 160 Rezult:False Count true:1
#
# Ticket 161 Rezult:False Count true:1
#
# Ticket 162 Rezult:False Count true:1
#
# Ticket 163 Rezult:False Count true:1
#
# Ticket 164 Rezult:False Count true:1
#
# Ticket 165 Rezult:False Count true:1
#
# Ticket 166 Rezult:False Count true:1
#
# Ticket 167 Rezult:False Count true:1
#
# Ticket 168 Rezult:False Count true:1
#
# Ticket 169 Rezult:False Count true:1
#
# Ticket 170 Rezult:False Count true:1
#
# Ticket 171 Rezult:False Count true:1
#
# Ticket 172 Rezult:False Count true:1
#
# Ticket 173 Rezult:False Count true:1
#
# Ticket 174 Rezult:False Count true:1
#
# Ticket 175 Rezult:False Count true:1
#
# Ticket 176 Rezult:False Count true:1
#
# Ticket 177 Rezult:False Count true:1
#
# Ticket 178 Rezult:False Count true:1
#
# Ticket 179 Rezult:False Count true:1
#
# Ticket 180 Rezult:False Count true:1
#
# Ticket 181 Rezult:False Count true:1
#
# Ticket 182 Rezult:False Count true:1
#
# Ticket 183 Rezult:False Count true:1
#
# Ticket 184 Rezult:False Count true:1
#
# Ticket 185 Rezult:False Count true:1
#
# Ticket 186 Rezult:False Count true:1
#
# Ticket 187 Rezult:False Count true:1
#
# Ticket 188 Rezult:False Count true:1
#
# Ticket 189 Rezult:False Count true:1
#
# Ticket 190 Rezult:False Count true:1
#
# Ticket 191 Rezult:False Count true:1
#
# Ticket 192 Rezult:False Count true:1
#
# Ticket 193 Rezult:False Count true:1
#
# Ticket 194 Rezult:False Count true:1
#
# Ticket 195 Rezult:False Count true:1
#
# Ticket 196 Rezult:False Count true:1
#
# Ticket 197 Rezult:False Count true:1
#
# Ticket 198 Rezult:False Count true:1
#
# Ticket 199 Rezult:True Count true:2
# 1 (1) + 99
#
# Ticket 200 Rezult:False Count true:2
#
# Ticket 201 Rezult:False Count true:2
#
# Ticket 202 Rezult:False Count true:2
#
# Ticket 203 Rezult:False Count true:2
#
# Ticket 204 Rezult:False Count true:2
#
# Ticket 205 Rezult:True Count true:3
# 20 (1) * 5
#
# Ticket 206 Rezult:False Count true:3
#
# Ticket 207 Rezult:False Count true:3
#
# Ticket 208 Rezult:False Count true:3
#
# Ticket 209 Rezult:False Count true:3
#
# Ticket 210 Rezult:False Count true:3
#
# Ticket 211 Rezult:False Count true:3
#
# Ticket 212 Rezult:False Count true:3
#
# Ticket 213 Rezult:False Count true:3
#
# Ticket 214 Rezult:False Count true:3
#
# Ticket 215 Rezult:False Count true:3
#
# Ticket 216 Rezult:False Count true:3
#
# Ticket 217 Rezult:False Count true:3
#
# Ticket 218 Rezult:False Count true:3
#
# Ticket 219 Rezult:False Count true:3
#
# Ticket 220 Rezult:False Count true:3
#
# Ticket 221 Rezult:False Count true:3
#
# Ticket 222 Rezult:False Count true:3
#
# Ticket 223 Rezult:False Count true:3
#
# Ticket 224 Rezult:False Count true:3
#
# Ticket 225 Rezult:False Count true:3
#
# Ticket 226 Rezult:False Count true:3
#
# Ticket 227 Rezult:False Count true:3
#
# Ticket 228 Rezult:False Count true:3
#
# Ticket 229 Rezult:False Count true:3
#
# Ticket 230 Rezult:False Count true:3
#
# Ticket 231 Rezult:False Count true:3
#
# Ticket 232 Rezult:False Count true:3
#
# Ticket 233 Rezult:False Count true:3
#
# Ticket 234 Rezult:False Count true:3
#
# Ticket 235 Rezult:False Count true:3
#
# Ticket 236 Rezult:False Count true:3
#
# Ticket 237 Rezult:False Count true:3
#
# Ticket 238 Rezult:False Count true:3
#
# Ticket 239 Rezult:False Count true:3
#
# Ticket 240 Rezult:False Count true:3
#
# Ticket 241 Rezult:False Count true:3
#
# Ticket 242 Rezult:False Count true:3
#
# Ticket 243 Rezult:False Count true:3
#
# Ticket 244 Rezult:False Count true:3
#
# Ticket 245 Rezult:False Count true:3
#
# Ticket 246 Rezult:False Count true:3
#
# Ticket 247 Rezult:False Count true:3
#
# Ticket 248 Rezult:False Count true:3
#
# Ticket 249 Rezult:False Count true:3
#
# Ticket 250 Rezult:True Count true:4
# 2 (1) * 50
#
# Ticket 251 Rezult:False Count true:4
#
# Ticket 252 Rezult:False Count true:4
#
# Ticket 253 Rezult:False Count true:4
#
# Ticket 254 Rezult:True Count true:5
# 25 (1) * 4
#
# Ticket 255 Rezult:False Count true:5
#
# Ticket 256 Rezult:False Count true:5
#
# Ticket 257 Rezult:False Count true:5
#
# Ticket 258 Rezult:False Count true:5
#
# Ticket 259 Rezult:False Count true:5
#
# Ticket 260 Rezult:False Count true:5
#
# Ticket 261 Rezult:False Count true:5
#
# Ticket 262 Rezult:False Count true:5
#
# Ticket 263 Rezult:False Count true:5
#
# Ticket 264 Rezult:False Count true:5
#
# Ticket 265 Rezult:False Count true:5
#
# Ticket 266 Rezult:False Count true:5
#
# Ticket 267 Rezult:False Count true:5
#
# Ticket 268 Rezult:False Count true:5
#
# Ticket 269 Rezult:False Count true:5
#
# Ticket 270 Rezult:False Count true:5
#
# Ticket 271 Rezult:False Count true:5
#
# Ticket 272 Rezult:False Count true:5
#
# Ticket 273 Rezult:False Count true:5
#
# Ticket 274 Rezult:False Count true:5
#
# Ticket 275 Rezult:False Count true:5
#
# Ticket 276 Rezult:False Count true:5
#
# Ticket 277 Rezult:False Count true:5
#
# Ticket 278 Rezult:False Count true:5
#
# Ticket 279 Rezult:False Count true:5
#
# Ticket 280 Rezult:False Count true:5
#
# Ticket 281 Rezult:False Count true:5
#
# Ticket 282 Rezult:False Count true:5
#
# Ticket 283 Rezult:False Count true:5
#
# Ticket 284 Rezult:False Count true:5
#
# Ticket 285 Rezult:False Count true:5
#
# Ticket 286 Rezult:False Count true:5
#
# Ticket 287 Rezult:False Count true:5
#
# Ticket 288 Rezult:False Count true:5
#
# Ticket 289 Rezult:False Count true:5
#
# Ticket 290 Rezult:False Count true:5
#
# Ticket 291 Rezult:False Count true:5
#
# Ticket 292 Rezult:False Count true:5
#
# Ticket 293 Rezult:False Count true:5
#
# Ticket 294 Rezult:False Count true:5
#
# Ticket 295 Rezult:False Count true:5
#
# Ticket 296 Rezult:False Count true:5
#
# Ticket 297 Rezult:False Count true:5
#
# Ticket 298 Rezult:True Count true:6
# 2 (1) + 98
#
# Ticket 299 Rezult:False Count true:6
#
# Ticket 300 Rezult:False Count true:6
#
# Ticket 301 Rezult:False Count true:6
#
# Ticket 302 Rezult:False Count true:6
#
# Ticket 303 Rezult:False Count true:6
#
# Ticket 304 Rezult:False Count true:6
#
# Ticket 305 Rezult:False Count true:6
#
# Ticket 306 Rezult:False Count true:6
#
# Ticket 307 Rezult:False Count true:6
#
# Ticket 308 Rezult:False Count true:6
#
# Ticket 309 Rezult:False Count true:6
#
# Ticket 310 Rezult:False Count true:6
#
# Ticket 311 Rezult:False Count true:6
#
# Ticket 312 Rezult:False Count true:6
#
# Ticket 313 Rezult:False Count true:6
#
# Ticket 314 Rezult:False Count true:6
#
# Ticket 315 Rezult:False Count true:6
#
# Ticket 316 Rezult:False Count true:6
#
# Ticket 317 Rezult:False Count true:6
#
# Ticket 318 Rezult:False Count true:6
#
# Ticket 319 Rezult:False Count true:6
#
# Ticket 320 Rezult:False Count true:6
#
# Ticket 321 Rezult:False Count true:6
#
# Ticket 322 Rezult:False Count true:6
#
# Ticket 323 Rezult:False Count true:6
#
# Ticket 324 Rezult:False Count true:6
#
# Ticket 325 Rezult:False Count true:6
#
# Ticket 326 Rezult:False Count true:6
#
# Ticket 327 Rezult:False Count true:6
#
# Ticket 328 Rezult:False Count true:6
#
# Ticket 329 Rezult:False Count true:6
#
# Ticket 330 Rezult:False Count true:6
#
# Ticket 331 Rezult:False Count true:6
#
# Ticket 332 Rezult:False Count true:6
#
# Ticket 333 Rezult:False Count true:6
#
# Ticket 334 Rezult:False Count true:6
#
# Ticket 335 Rezult:False Count true:6
#
# Ticket 336 Rezult:False Count true:6
#
# Ticket 337 Rezult:False Count true:6
#
# Ticket 338 Rezult:False Count true:6
#
# Ticket 339 Rezult:False Count true:6
#
# Ticket 340 Rezult:False Count true:6
#
# Ticket 341 Rezult:False Count true:6
#
# Ticket 342 Rezult:False Count true:6
#
# Ticket 343 Rezult:False Count true:6
#
# Ticket 344 Rezult:False Count true:6
#
# Ticket 345 Rezult:False Count true:6
#
# Ticket 346 Rezult:False Count true:6
#
# Ticket 347 Rezult:False Count true:6
#
# Ticket 348 Rezult:False Count true:6
#
# Ticket 349 Rezult:False Count true:6
#
# Ticket 350 Rezult:False Count true:6
#
# Ticket 351 Rezult:False Count true:6
#
# Ticket 352 Rezult:False Count true:6
#
# Ticket 353 Rezult:False Count true:6
#
# Ticket 354 Rezult:False Count true:6
#
# Ticket 355 Rezult:False Count true:6
#
# Ticket 356 Rezult:False Count true:6
#
# Ticket 357 Rezult:False Count true:6
#
# Ticket 358 Rezult:False Count true:6
#
# Ticket 359 Rezult:False Count true:6
#
# Ticket 360 Rezult:False Count true:6
#
# Ticket 361 Rezult:False Count true:6
#
# Ticket 362 Rezult:False Count true:6
#
# Ticket 363 Rezult:False Count true:6
#
# Ticket 364 Rezult:False Count true:6
#
# Ticket 365 Rezult:False Count true:6
#
# Ticket 366 Rezult:False Count true:6
#
# Ticket 367 Rezult:False Count true:6
#
# Ticket 368 Rezult:False Count true:6
#
# Ticket 369 Rezult:False Count true:6
#
# Ticket 370 Rezult:False Count true:6
#
# Ticket 371 Rezult:False Count true:6
#
# Ticket 372 Rezult:False Count true:6
#
# Ticket 373 Rezult:False Count true:6
#
# Ticket 374 Rezult:False Count true:6
#
# Ticket 375 Rezult:False Count true:6
#
# Ticket 376 Rezult:False Count true:6
#
# Ticket 377 Rezult:False Count true:6
#
# Ticket 378 Rezult:False Count true:6
#
# Ticket 379 Rezult:False Count true:6
#
# Ticket 380 Rezult:False Count true:6
#
# Ticket 381 Rezult:False Count true:6
#
# Ticket 382 Rezult:False Count true:6
#
# Ticket 383 Rezult:False Count true:6
#
# Ticket 384 Rezult:False Count true:6
#
# Ticket 385 Rezult:False Count true:6
#
# Ticket 386 Rezult:False Count true:6
#
# Ticket 387 Rezult:False Count true:6
#
# Ticket 388 Rezult:False Count true:6
#
# Ticket 389 Rezult:False Count true:6
#
# Ticket 390 Rezult:False Count true:6
#
# Ticket 391 Rezult:False Count true:6
#
# Ticket 392 Rezult:False Count true:6
#
# Ticket 393 Rezult:False Count true:6
#
# Ticket 394 Rezult:False Count true:6
#
# Ticket 395 Rezult:False Count true:6
#
# Ticket 396 Rezult:False Count true:6
#
# Ticket 397 Rezult:True Count true:7
# 3 (1) + 97
#
# Ticket 398 Rezult:False Count true:7
#
# Ticket 399 Rezult:False Count true:7
#
# Ticket 400 Rezult:False Count true:7
#
# Ticket 401 Rezult:False Count true:7
#
# Ticket 402 Rezult:False Count true:7
#
# Ticket 403 Rezult:False Count true:7
#
# Ticket 404 Rezult:False Count true:7
#
# Ticket 405 Rezult:False Count true:7
#
# Ticket 406 Rezult:False Count true:7
#
# Ticket 407 Rezult:False Count true:7
#
# Ticket 408 Rezult:False Count true:7
#
# Ticket 409 Rezult:False Count true:7
#
# Ticket 410 Rezult:False Count true:7
#
# Ticket 411 Rezult:False Count true:7
#
# Ticket 412 Rezult:False Count true:7
#
# Ticket 413 Rezult:False Count true:7
#
# Ticket 414 Rezult:False Count true:7
#
# Ticket 415 Rezult:False Count true:7
#
# Ticket 416 Rezult:False Count true:7
#
# Ticket 417 Rezult:False Count true:7
#
# Ticket 418 Rezult:False Count true:7
#
# Ticket 419 Rezult:False Count true:7
#
# Ticket 420 Rezult:False Count true:7
#
# Ticket 421 Rezult:False Count true:7
#
# Ticket 422 Rezult:False Count true:7
#
# Ticket 423 Rezult:False Count true:7
#
# Ticket 424 Rezult:False Count true:7
#
# Ticket 425 Rezult:True Count true:8
# 4 (1) * 25
#
# Ticket 426 Rezult:False Count true:8
#
# Ticket 427 Rezult:False Count true:8
#
# Ticket 428 Rezult:False Count true:8
#
# Ticket 429 Rezult:False Count true:8
#
# Ticket 430 Rezult:False Count true:8
#
# Ticket 431 Rezult:False Count true:8
#
# Ticket 432 Rezult:False Count true:8
#
# Ticket 433 Rezult:False Count true:8
#
# Ticket 434 Rezult:False Count true:8
#
# Ticket 435 Rezult:False Count true:8
#
# Ticket 436 Rezult:False Count true:8
#
# Ticket 437 Rezult:False Count true:8
#
# Ticket 438 Rezult:False Count true:8
#
# Ticket 439 Rezult:False Count true:8
#
# Ticket 440 Rezult:False Count true:8
#
# Ticket 441 Rezult:False Count true:8
#
# Ticket 442 Rezult:False Count true:8
#
# Ticket 443 Rezult:False Count true:8
#
# Ticket 444 Rezult:False Count true:8
#
# Ticket 445 Rezult:False Count true:8
#
# Ticket 446 Rezult:False Count true:8
#
# Ticket 447 Rezult:False Count true:8
#
# Ticket 448 Rezult:False Count true:8
#
# Ticket 449 Rezult:False Count true:8
#
# Ticket 450 Rezult:False Count true:8
#
# Ticket 451 Rezult:False Count true:8
#
# Ticket 452 Rezult:False Count true:8
#
# Ticket 453 Rezult:False Count true:8
#
# Ticket 454 Rezult:False Count true:8
#
# Ticket 455 Rezult:True Count true:9
# 4 (1) * 5 (2) * 5
#
# Ticket 456 Rezult:False Count true:9
#
# Ticket 457 Rezult:False Count true:9
#
# Ticket 458 Rezult:False Count true:9
#
# Ticket 459 Rezult:False Count true:9
#
# Ticket 460 Rezult:False Count true:9
#
# Ticket 461 Rezult:False Count true:9
#
# Ticket 462 Rezult:False Count true:9
#
# Ticket 463 Rezult:False Count true:9
#
# Ticket 464 Rezult:False Count true:9
#
# Ticket 465 Rezult:False Count true:9
#
# Ticket 466 Rezult:False Count true:9
#
# Ticket 467 Rezult:False Count true:9
#
# Ticket 468 Rezult:False Count true:9
#
# Ticket 469 Rezult:False Count true:9
#
# Ticket 470 Rezult:False Count true:9
#
# Ticket 471 Rezult:False Count true:9
#
# Ticket 472 Rezult:False Count true:9
#
# Ticket 473 Rezult:False Count true:9
#
# Ticket 474 Rezult:False Count true:9
#
# Ticket 475 Rezult:False Count true:9
#
# Ticket 476 Rezult:False Count true:9
#
# Ticket 477 Rezult:False Count true:9
#
# Ticket 478 Rezult:False Count true:9
#
# Ticket 479 Rezult:False Count true:9
#
# Ticket 480 Rezult:False Count true:9
#
# Ticket 481 Rezult:False Count true:9
#
# Ticket 482 Rezult:False Count true:9
#
# Ticket 483 Rezult:False Count true:9
#
# Ticket 484 Rezult:False Count true:9
#
# Ticket 485 Rezult:False Count true:9
#
# Ticket 486 Rezult:False Count true:9
#
# Ticket 487 Rezult:False Count true:9
#
# Ticket 488 Rezult:False Count true:9
#
# Ticket 489 Rezult:False Count true:9
#
# Ticket 490 Rezult:False Count true:9
#
# Ticket 491 Rezult:False Count true:9
#
# Ticket 492 Rezult:False Count true:9
#
# Ticket 493 Rezult:False Count true:9
#
# Ticket 494 Rezult:False Count true:9
#
# Ticket 495 Rezult:False Count true:9
#
# Ticket 496 Rezult:True Count true:10
# 4 (1) + 96
#
# Ticket 497 Rezult:False Count true:10
#
# Ticket 498 Rezult:False Count true:10
#
# Ticket 499 Rezult:False Count true:10
#
# Ticket 500 Rezult:False Count true:10
#
# Ticket 501 Rezult:False Count true:10
#
# Ticket 502 Rezult:True Count true:11
# 50 (1) * 2
#
# Ticket 503 Rezult:False Count true:11
#
# Ticket 504 Rezult:False Count true:11
#
# Ticket 505 Rezult:False Count true:11
#
# Ticket 506 Rezult:False Count true:11
#
# Ticket 507 Rezult:False Count true:11
#
# Ticket 508 Rezult:False Count true:11
#
# Ticket 509 Rezult:False Count true:11
#
# Ticket 510 Rezult:False Count true:11
#
# Ticket 511 Rezult:False Count true:11
#
# Ticket 512 Rezult:False Count true:11
#
# Ticket 513 Rezult:False Count true:11
#
# Ticket 514 Rezult:False Count true:11
#
# Ticket 515 Rezult:False Count true:11
#
# Ticket 516 Rezult:False Count true:11
#
# Ticket 517 Rezult:False Count true:11
#
# Ticket 518 Rezult:False Count true:11
#
# Ticket 519 Rezult:False Count true:11
#
# Ticket 520 Rezult:True Count true:12
# 5 (1) * 20
#
# Ticket 521 Rezult:False Count true:12
#
# Ticket 522 Rezult:False Count true:12
#
# Ticket 523 Rezult:False Count true:12
#
# Ticket 524 Rezult:False Count true:12
#
# Ticket 525 Rezult:False Count true:12
#
# Ticket 526 Rezult:False Count true:12
#
# Ticket 527 Rezult:False Count true:12
#
# Ticket 528 Rezult:False Count true:12
#
# Ticket 529 Rezult:False Count true:12
#
# Ticket 530 Rezult:False Count true:12
#
# Ticket 531 Rezult:False Count true:12
#
# Ticket 532 Rezult:False Count true:12
#
# Ticket 533 Rezult:False Count true:12
#
# Ticket 534 Rezult:False Count true:12
#
# Ticket 535 Rezult:False Count true:12
#
# Ticket 536 Rezult:False Count true:12
#
# Ticket 537 Rezult:False Count true:12
#
# Ticket 538 Rezult:False Count true:12
#
# Ticket 539 Rezult:False Count true:12
#
# Ticket 540 Rezult:False Count true:12
#
# Ticket 541 Rezult:False Count true:12
#
# Ticket 542 Rezult:False Count true:12
#
# Ticket 543 Rezult:False Count true:12
#
# Ticket 544 Rezult:False Count true:12
#
# Ticket 545 Rezult:True Count true:13
# 5 (1) * 4 (2) * 5
#
# Ticket 546 Rezult:False Count true:13
#
# Ticket 547 Rezult:False Count true:13
#
# Ticket 548 Rezult:False Count true:13
#
# Ticket 549 Rezult:False Count true:13
#
# Ticket 550 Rezult:False Count true:13
#
# Ticket 551 Rezult:False Count true:13
#
# Ticket 552 Rezult:False Count true:13
#
# Ticket 553 Rezult:False Count true:13
#
# Ticket 554 Rezult:True Count true:14
# 5 (1) * 5 (2) * 4
#
# Ticket 555 Rezult:False Count true:14
#
# Ticket 556 Rezult:False Count true:14
#
# Ticket 557 Rezult:False Count true:14
#
# Ticket 558 Rezult:False Count true:14
#
# Ticket 559 Rezult:False Count true:14
#
# Ticket 560 Rezult:False Count true:14
#
# Ticket 561 Rezult:False Count true:14
#
# Ticket 562 Rezult:False Count true:14
#
# Ticket 563 Rezult:False Count true:14
#
# Ticket 564 Rezult:False Count true:14
#
# Ticket 565 Rezult:False Count true:14
#
# Ticket 566 Rezult:False Count true:14
#
# Ticket 567 Rezult:False Count true:14
#
# Ticket 568 Rezult:False Count true:14
#
# Ticket 569 Rezult:False Count true:14
#
# Ticket 570 Rezult:False Count true:14
#
# Ticket 571 Rezult:False Count true:14
#
# Ticket 572 Rezult:False Count true:14
#
# Ticket 573 Rezult:False Count true:14
#
# Ticket 574 Rezult:False Count true:14
#
# Ticket 575 Rezult:False Count true:14
#
# Ticket 576 Rezult:False Count true:14
#
# Ticket 577 Rezult:False Count true:14
#
# Ticket 578 Rezult:False Count true:14
#
# Ticket 579 Rezult:False Count true:14
#
# Ticket 580 Rezult:False Count true:14
#
# Ticket 581 Rezult:False Count true:14
#
# Ticket 582 Rezult:False Count true:14
#
# Ticket 583 Rezult:False Count true:14
#
# Ticket 584 Rezult:False Count true:14
#
# Ticket 585 Rezult:False Count true:14
#
# Ticket 586 Rezult:False Count true:14
#
# Ticket 587 Rezult:False Count true:14
#
# Ticket 588 Rezult:False Count true:14
#
# Ticket 589 Rezult:False Count true:14
#
# Ticket 590 Rezult:False Count true:14
#
# Ticket 591 Rezult:False Count true:14
#
# Ticket 592 Rezult:False Count true:14
#
# Ticket 593 Rezult:False Count true:14
#
# Ticket 594 Rezult:False Count true:14
#
# Ticket 595 Rezult:True Count true:15
# 5 (1) + 95
#
# Ticket 596 Rezult:False Count true:15
#
# Ticket 597 Rezult:False Count true:15
#
# Ticket 598 Rezult:False Count true:15
#
# Ticket 599 Rezult:False Count true:15
#
# Ticket 600 Rezult:False Count true:15
#
# Ticket 601 Rezult:False Count true:15
#
# Ticket 602 Rezult:False Count true:15
#
# Ticket 603 Rezult:False Count true:15
#
# Ticket 604 Rezult:False Count true:15
#
# Ticket 605 Rezult:False Count true:15
#
# Ticket 606 Rezult:False Count true:15
#
# Ticket 607 Rezult:False Count true:15
#
# Ticket 608 Rezult:False Count true:15
#
# Ticket 609 Rezult:False Count true:15
#
# Ticket 610 Rezult:False Count true:15
#
# Ticket 611 Rezult:False Count true:15
#
# Ticket 612 Rezult:False Count true:15
#
# Ticket 613 Rezult:False Count true:15
#
# Ticket 614 Rezult:False Count true:15
#
# Ticket 615 Rezult:False Count true:15
#
# Ticket 616 Rezult:False Count true:15
#
# Ticket 617 Rezult:False Count true:15
#
# Ticket 618 Rezult:False Count true:15
#
# Ticket 619 Rezult:False Count true:15
#
# Ticket 620 Rezult:False Count true:15
#
# Ticket 621 Rezult:False Count true:15
#
# Ticket 622 Rezult:False Count true:15
#
# Ticket 623 Rezult:False Count true:15
#
# Ticket 624 Rezult:False Count true:15
#
# Ticket 625 Rezult:False Count true:15
#
# Ticket 626 Rezult:False Count true:15
#
# Ticket 627 Rezult:False Count true:15
#
# Ticket 628 Rezult:False Count true:15
#
# Ticket 629 Rezult:False Count true:15
#
# Ticket 630 Rezult:False Count true:15
#
# Ticket 631 Rezult:False Count true:15
#
# Ticket 632 Rezult:False Count true:15
#
# Ticket 633 Rezult:False Count true:15
#
# Ticket 634 Rezult:False Count true:15
#
# Ticket 635 Rezult:False Count true:15
#
# Ticket 636 Rezult:False Count true:15
#
# Ticket 637 Rezult:False Count true:15
#
# Ticket 638 Rezult:False Count true:15
#
# Ticket 639 Rezult:False Count true:15
#
# Ticket 640 Rezult:False Count true:15
#
# Ticket 641 Rezult:False Count true:15
#
# Ticket 642 Rezult:False Count true:15
#
# Ticket 643 Rezult:False Count true:15
#
# Ticket 644 Rezult:False Count true:15
#
# Ticket 645 Rezult:False Count true:15
#
# Ticket 646 Rezult:False Count true:15
#
# Ticket 647 Rezult:False Count true:15
#
# Ticket 648 Rezult:False Count true:15
#
# Ticket 649 Rezult:False Count true:15
#
# Ticket 650 Rezult:False Count true:15
#
# Ticket 651 Rezult:False Count true:15
#
# Ticket 652 Rezult:False Count true:15
#
# Ticket 653 Rezult:False Count true:15
#
# Ticket 654 Rezult:False Count true:15
#
# Ticket 655 Rezult:False Count true:15
#
# Ticket 656 Rezult:False Count true:15
#
# Ticket 657 Rezult:False Count true:15
#
# Ticket 658 Rezult:False Count true:15
#
# Ticket 659 Rezult:False Count true:15
#
# Ticket 660 Rezult:False Count true:15
#
# Ticket 661 Rezult:False Count true:15
#
# Ticket 662 Rezult:False Count true:15
#
# Ticket 663 Rezult:False Count true:15
#
# Ticket 664 Rezult:False Count true:15
#
# Ticket 665 Rezult:False Count true:15
#
# Ticket 666 Rezult:False Count true:15
#
# Ticket 667 Rezult:False Count true:15
#
# Ticket 668 Rezult:False Count true:15
#
# Ticket 669 Rezult:False Count true:15
#
# Ticket 670 Rezult:False Count true:15
#
# Ticket 671 Rezult:False Count true:15
#
# Ticket 672 Rezult:False Count true:15
#
# Ticket 673 Rezult:False Count true:15
#
# Ticket 674 Rezult:False Count true:15
#
# Ticket 675 Rezult:False Count true:15
#
# Ticket 676 Rezult:False Count true:15
#
# Ticket 677 Rezult:False Count true:15
#
# Ticket 678 Rezult:False Count true:15
#
# Ticket 679 Rezult:False Count true:15
#
# Ticket 680 Rezult:False Count true:15
#
# Ticket 681 Rezult:False Count true:15
#
# Ticket 682 Rezult:False Count true:15
#
# Ticket 683 Rezult:False Count true:15
#
# Ticket 684 Rezult:False Count true:15
#
# Ticket 685 Rezult:False Count true:15
#
# Ticket 686 Rezult:False Count true:15
#
# Ticket 687 Rezult:False Count true:15
#
# Ticket 688 Rezult:False Count true:15
#
# Ticket 689 Rezult:False Count true:15
#
# Ticket 690 Rezult:False Count true:15
#
# Ticket 691 Rezult:False Count true:15
#
# Ticket 692 Rezult:False Count true:15
#
# Ticket 693 Rezult:False Count true:15
#
# Ticket 694 Rezult:True Count true:16
# 6 (1) + 94
#
# Ticket 695 Rezult:False Count true:16
#
# Ticket 696 Rezult:False Count true:16
#
# Ticket 697 Rezult:False Count true:16
#
# Ticket 698 Rezult:False Count true:16
#
# Ticket 699 Rezult:False Count true:16
#
# Ticket 700 Rezult:False Count true:16
#
# Ticket 701 Rezult:False Count true:16
#
# Ticket 702 Rezult:False Count true:16
#
# Ticket 703 Rezult:False Count true:16
#
# Ticket 704 Rezult:False Count true:16
#
# Ticket 705 Rezult:False Count true:16
#
# Ticket 706 Rezult:False Count true:16
#
# Ticket 707 Rezult:False Count true:16
#
# Ticket 708 Rezult:False Count true:16
#
# Ticket 709 Rezult:False Count true:16
#
# Ticket 710 Rezult:False Count true:16
#
# Ticket 711 Rezult:False Count true:16
#
# Ticket 712 Rezult:False Count true:16
#
# Ticket 713 Rezult:False Count true:16
#
# Ticket 714 Rezult:False Count true:16
#
# Ticket 715 Rezult:False Count true:16
#
# Ticket 716 Rezult:False Count true:16
#
# Ticket 717 Rezult:False Count true:16
#
# Ticket 718 Rezult:False Count true:16
#
# Ticket 719 Rezult:False Count true:16
#
# Ticket 720 Rezult:False Count true:16
#
# Ticket 721 Rezult:False Count true:16
#
# Ticket 722 Rezult:False Count true:16
#
# Ticket 723 Rezult:False Count true:16
#
# Ticket 724 Rezult:False Count true:16
#
# Ticket 725 Rezult:False Count true:16
#
# Ticket 726 Rezult:False Count true:16
#
# Ticket 727 Rezult:False Count true:16
#
# Ticket 728 Rezult:False Count true:16
#
# Ticket 729 Rezult:False Count true:16
#
# Ticket 730 Rezult:False Count true:16
#
# Ticket 731 Rezult:False Count true:16
#
# Ticket 732 Rezult:False Count true:16
#
# Ticket 733 Rezult:False Count true:16
#
# Ticket 734 Rezult:False Count true:16
#
# Ticket 735 Rezult:False Count true:16
#
# Ticket 736 Rezult:False Count true:16
#
# Ticket 737 Rezult:False Count true:16
#
# Ticket 738 Rezult:False Count true:16
#
# Ticket 739 Rezult:False Count true:16
#
# Ticket 740 Rezult:False Count true:16
#
# Ticket 741 Rezult:False Count true:16
#
# Ticket 742 Rezult:False Count true:16
#
# Ticket 743 Rezult:False Count true:16
#
# Ticket 744 Rezult:False Count true:16
#
# Ticket 745 Rezult:False Count true:16
#
# Ticket 746 Rezult:False Count true:16
#
# Ticket 747 Rezult:False Count true:16
#
# Ticket 748 Rezult:False Count true:16
#
# Ticket 749 Rezult:False Count true:16
#
# Ticket 750 Rezult:False Count true:16
#
# Ticket 751 Rezult:False Count true:16
#
# Ticket 752 Rezult:False Count true:16
#
# Ticket 753 Rezult:False Count true:16
#
# Ticket 754 Rezult:False Count true:16
#
# Ticket 755 Rezult:False Count true:16
#
# Ticket 756 Rezult:False Count true:16
#
# Ticket 757 Rezult:False Count true:16
#
# Ticket 758 Rezult:False Count true:16
#
# Ticket 759 Rezult:False Count true:16
#
# Ticket 760 Rezult:False Count true:16
#
# Ticket 761 Rezult:False Count true:16
#
# Ticket 762 Rezult:False Count true:16
#
# Ticket 763 Rezult:False Count true:16
#
# Ticket 764 Rezult:False Count true:16
#
# Ticket 765 Rezult:False Count true:16
#
# Ticket 766 Rezult:False Count true:16
#
# Ticket 767 Rezult:False Count true:16
#
# Ticket 768 Rezult:False Count true:16
#
# Ticket 769 Rezult:False Count true:16
#
# Ticket 770 Rezult:False Count true:16
#
# Ticket 771 Rezult:False Count true:16
#
# Ticket 772 Rezult:False Count true:16
#
# Ticket 773 Rezult:False Count true:16
#
# Ticket 774 Rezult:False Count true:16
#
# Ticket 775 Rezult:False Count true:16
#
# Ticket 776 Rezult:False Count true:16
#
# Ticket 777 Rezult:False Count true:16
#
# Ticket 778 Rezult:False Count true:16
#
# Ticket 779 Rezult:False Count true:16
#
# Ticket 780 Rezult:False Count true:16
#
# Ticket 781 Rezult:False Count true:16
#
# Ticket 782 Rezult:False Count true:16
#
# Ticket 783 Rezult:False Count true:16
#
# Ticket 784 Rezult:False Count true:16
#
# Ticket 785 Rezult:False Count true:16
#
# Ticket 786 Rezult:False Count true:16
#
# Ticket 787 Rezult:False Count true:16
#
# Ticket 788 Rezult:False Count true:16
#
# Ticket 789 Rezult:False Count true:16
#
# Ticket 790 Rezult:False Count true:16
#
# Ticket 791 Rezult:False Count true:16
#
# Ticket 792 Rezult:False Count true:16
#
# Ticket 793 Rezult:True Count true:17
# 7 (1) + 93
#
# Ticket 794 Rezult:False Count true:17
#
# Ticket 795 Rezult:False Count true:17
#
# Ticket 796 Rezult:False Count true:17
#
# Ticket 797 Rezult:False Count true:17
#
# Ticket 798 Rezult:False Count true:17
#
# Ticket 799 Rezult:False Count true:17
#
# Ticket 800 Rezult:False Count true:17
#
# Ticket 801 Rezult:False Count true:17
#
# Ticket 802 Rezult:False Count true:17
#
# Ticket 803 Rezult:False Count true:17
#
# Ticket 804 Rezult:False Count true:17
#
# Ticket 805 Rezult:False Count true:17
#
# Ticket 806 Rezult:False Count true:17
#
# Ticket 807 Rezult:False Count true:17
#
# Ticket 808 Rezult:False Count true:17
#
# Ticket 809 Rezult:False Count true:17
#
# Ticket 810 Rezult:False Count true:17
#
# Ticket 811 Rezult:False Count true:17
#
# Ticket 812 Rezult:False Count true:17
#
# Ticket 813 Rezult:False Count true:17
#
# Ticket 814 Rezult:False Count true:17
#
# Ticket 815 Rezult:False Count true:17
#
# Ticket 816 Rezult:False Count true:17
#
# Ticket 817 Rezult:False Count true:17
#
# Ticket 818 Rezult:False Count true:17
#
# Ticket 819 Rezult:False Count true:17
#
# Ticket 820 Rezult:False Count true:17
#
# Ticket 821 Rezult:False Count true:17
#
# Ticket 822 Rezult:False Count true:17
#
# Ticket 823 Rezult:False Count true:17
#
# Ticket 824 Rezult:False Count true:17
#
# Ticket 825 Rezult:False Count true:17
#
# Ticket 826 Rezult:False Count true:17
#
# Ticket 827 Rezult:False Count true:17
#
# Ticket 828 Rezult:False Count true:17
#
# Ticket 829 Rezult:False Count true:17
#
# Ticket 830 Rezult:False Count true:17
#
# Ticket 831 Rezult:False Count true:17
#
# Ticket 832 Rezult:False Count true:17
#
# Ticket 833 Rezult:False Count true:17
#
# Ticket 834 Rezult:False Count true:17
#
# Ticket 835 Rezult:False Count true:17
#
# Ticket 836 Rezult:False Count true:17
#
# Ticket 837 Rezult:False Count true:17
#
# Ticket 838 Rezult:False Count true:17
#
# Ticket 839 Rezult:False Count true:17
#
# Ticket 840 Rezult:False Count true:17
#
# Ticket 841 Rezult:False Count true:17
#
# Ticket 842 Rezult:False Count true:17
#
# Ticket 843 Rezult:False Count true:17
#
# Ticket 844 Rezult:False Count true:17
#
# Ticket 845 Rezult:False Count true:17
#
# Ticket 846 Rezult:False Count true:17
#
# Ticket 847 Rezult:False Count true:17
#
# Ticket 848 Rezult:False Count true:17
#
# Ticket 849 Rezult:False Count true:17
#
# Ticket 850 Rezult:False Count true:17
#
# Ticket 851 Rezult:False Count true:17
#
# Ticket 852 Rezult:False Count true:17
#
# Ticket 853 Rezult:False Count true:17
#
# Ticket 854 Rezult:False Count true:17
#
# Ticket 855 Rezult:False Count true:17
#
# Ticket 856 Rezult:False Count true:17
#
# Ticket 857 Rezult:False Count true:17
#
# Ticket 858 Rezult:False Count true:17
#
# Ticket 859 Rezult:False Count true:17
#
# Ticket 860 Rezult:False Count true:17
#
# Ticket 861 Rezult:False Count true:17
#
# Ticket 862 Rezult:False Count true:17
#
# Ticket 863 Rezult:False Count true:17
#
# Ticket 864 Rezult:False Count true:17
#
# Ticket 865 Rezult:False Count true:17
#
# Ticket 866 Rezult:False Count true:17
#
# Ticket 867 Rezult:False Count true:17
#
# Ticket 868 Rezult:False Count true:17
#
# Ticket 869 Rezult:False Count true:17
#
# Ticket 870 Rezult:False Count true:17
#
# Ticket 871 Rezult:False Count true:17
#
# Ticket 872 Rezult:False Count true:17
#
# Ticket 873 Rezult:False Count true:17
#
# Ticket 874 Rezult:False Count true:17
#
# Ticket 875 Rezult:False Count true:17
#
# Ticket 876 Rezult:False Count true:17
#
# Ticket 877 Rezult:False Count true:17
#
# Ticket 878 Rezult:False Count true:17
#
# Ticket 879 Rezult:False Count true:17
#
# Ticket 880 Rezult:False Count true:17
#
# Ticket 881 Rezult:False Count true:17
#
# Ticket 882 Rezult:False Count true:17
#
# Ticket 883 Rezult:False Count true:17
#
# Ticket 884 Rezult:False Count true:17
#
# Ticket 885 Rezult:False Count true:17
#
# Ticket 886 Rezult:False Count true:17
#
# Ticket 887 Rezult:False Count true:17
#
# Ticket 888 Rezult:False Count true:17
#
# Ticket 889 Rezult:False Count true:17
#
# Ticket 890 Rezult:False Count true:17
#
# Ticket 891 Rezult:False Count true:17
#
# Ticket 892 Rezult:True Count true:18
# 8 (1) + 92
#
# Ticket 893 Rezult:False Count true:18
#
# Ticket 894 Rezult:False Count true:18
#
# Ticket 895 Rezult:False Count true:18
#
# Ticket 896 Rezult:False Count true:18
#
# Ticket 897 Rezult:False Count true:18
#
# Ticket 898 Rezult:False Count true:18
#
# Ticket 899 Rezult:False Count true:18
#
# Ticket 900 Rezult:False Count true:18
#
# Ticket 901 Rezult:False Count true:18
#
# Ticket 902 Rezult:False Count true:18
#
# Ticket 903 Rezult:False Count true:18
#
# Ticket 904 Rezult:False Count true:18
#
# Ticket 905 Rezult:False Count true:18
#
# Ticket 906 Rezult:False Count true:18
#
# Ticket 907 Rezult:False Count true:18
#
# Ticket 908 Rezult:False Count true:18
#
# Ticket 909 Rezult:False Count true:18
#
# Ticket 910 Rezult:False Count true:18
#
# Ticket 911 Rezult:False Count true:18
#
# Ticket 912 Rezult:False Count true:18
#
# Ticket 913 Rezult:False Count true:18
#
# Ticket 914 Rezult:False Count true:18
#
# Ticket 915 Rezult:False Count true:18
#
# Ticket 916 Rezult:False Count true:18
#
# Ticket 917 Rezult:False Count true:18
#
# Ticket 918 Rezult:False Count true:18
#
# Ticket 919 Rezult:True Count true:19
# 91 (1) + 9
#
# Ticket 920 Rezult:False Count true:19
#
# Ticket 921 Rezult:False Count true:19
#
# Ticket 922 Rezult:False Count true:19
#
# Ticket 923 Rezult:False Count true:19
#
# Ticket 924 Rezult:False Count true:19
#
# Ticket 925 Rezult:False Count true:19
#
# Ticket 926 Rezult:False Count true:19
#
# Ticket 927 Rezult:False Count true:19
#
# Ticket 928 Rezult:True Count true:20
# 92 (1) + 8
#
# Ticket 929 Rezult:False Count true:20
#
# Ticket 930 Rezult:False Count true:20
#
# Ticket 931 Rezult:False Count true:20
#
# Ticket 932 Rezult:False Count true:20
#
# Ticket 933 Rezult:False Count true:20
#
# Ticket 934 Rezult:False Count true:20
#
# Ticket 935 Rezult:False Count true:20
#
# Ticket 936 Rezult:False Count true:20
#
# Ticket 937 Rezult:True Count true:21
# 93 (1) + 7
#
# Ticket 938 Rezult:False Count true:21
#
# Ticket 939 Rezult:False Count true:21
#
# Ticket 940 Rezult:False Count true:21
#
# Ticket 941 Rezult:False Count true:21
#
# Ticket 942 Rezult:False Count true:21
#
# Ticket 943 Rezult:False Count true:21
#
# Ticket 944 Rezult:False Count true:21
#
# Ticket 945 Rezult:False Count true:21
#
# Ticket 946 Rezult:True Count true:22
# 94 (1) + 6
#
# Ticket 947 Rezult:False Count true:22
#
# Ticket 948 Rezult:False Count true:22
#
# Ticket 949 Rezult:False Count true:22
#
# Ticket 950 Rezult:False Count true:22
#
# Ticket 951 Rezult:False Count true:22
#
# Ticket 952 Rezult:False Count true:22
#
# Ticket 953 Rezult:False Count true:22
#
# Ticket 954 Rezult:False Count true:22
#
# Ticket 955 Rezult:True Count true:23
# 95 (1) + 5
#
# Ticket 956 Rezult:False Count true:23
#
# Ticket 957 Rezult:False Count true:23
#
# Ticket 958 Rezult:False Count true:23
#
# Ticket 959 Rezult:False Count true:23
#
# Ticket 960 Rezult:False Count true:23
#
# Ticket 961 Rezult:False Count true:23
#
# Ticket 962 Rezult:False Count true:23
#
# Ticket 963 Rezult:False Count true:23
#
# Ticket 964 Rezult:True Count true:24
# 96 (1) + 4
#
# Ticket 965 Rezult:False Count true:24
#
# Ticket 966 Rezult:False Count true:24
#
# Ticket 967 Rezult:False Count true:24
#
# Ticket 968 Rezult:False Count true:24
#
# Ticket 969 Rezult:False Count true:24
#
# Ticket 970 Rezult:False Count true:24
#
# Ticket 971 Rezult:False Count true:24
#
# Ticket 972 Rezult:False Count true:24
#
# Ticket 973 Rezult:True Count true:25
# 97 (1) + 3
#
# Ticket 974 Rezult:False Count true:25
#
# Ticket 975 Rezult:False Count true:25
#
# Ticket 976 Rezult:False Count true:25
#
# Ticket 977 Rezult:False Count true:25
#
# Ticket 978 Rezult:False Count true:25
#
# Ticket 979 Rezult:False Count true:25
#
# Ticket 980 Rezult:False Count true:25
#
# Ticket 981 Rezult:False Count true:25
#
# Ticket 982 Rezult:True Count true:26
# 98 (1) + 2
#
# Ticket 983 Rezult:False Count true:26
#
# Ticket 984 Rezult:False Count true:26
#
# Ticket 985 Rezult:False Count true:26
#
# Ticket 986 Rezult:False Count true:26
#
# Ticket 987 Rezult:False Count true:26
#
# Ticket 988 Rezult:False Count true:26
#
# Ticket 989 Rezult:False Count true:26
#
# Ticket 990 Rezult:False Count true:26
#
# Ticket 991 Rezult:True Count true:27
# 99 (1) + 1
#
# Ticket 992 Rezult:False Count true:27
#
# Ticket 993 Rezult:False Count true:27
#
# Ticket 994 Rezult:False Count true:27
#
# Ticket 995 Rezult:False Count true:27
#
# Ticket 996 Rezult:False Count true:27
#
# Ticket 997 Rezult:False Count true:27
#
# Ticket 998 Rezult:False Count true:27
#
# Ticket 999 Rezult:False Count true:27
#
# Ticket 1000 Rezult:True Count true:28
# 100 (1) + 0
#
# Ticket 1001 Rezult:True Count true:29
# 100 (1) * 1
#
# Ticket 1002 Rezult:False Count true:29
#
# Ticket 1003 Rezult:False Count true:29
#
# Ticket 1004 Rezult:False Count true:29
#
# Ticket 1005 Rezult:False Count true:29
#
# Ticket 1006 Rezult:False Count true:29
#
# Ticket 1007 Rezult:False Count true:29
#
# Ticket 1008 Rezult:False Count true:29
#
# Ticket 1009 Rezult:False Count true:29
#
# Ticket 1010 Rezult:True Count true:30
# 10 (1) * 10
#
# Ticket 1011 Rezult:True Count true:31
# 101 (1) - 1
