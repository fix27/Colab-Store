# %% [markdown]
# <a href="https://colab.research.google.com/github/fix27/Colab-Store/blob/main/fractalJuliaMandelbrot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# !git clone https://github.com/danilobellini/fractal.git
# %cd fractal
from IPython.display import Image

# !python -m fractal julia -0.644 --size=300x200 --depth=25 --zoom=0.6 --show --output=output.png
#images/julia_-0.644_size=300x200_depth=25_zoom=0.6.png
#Julia fractal

display(Image('output.png'))

# !python -m fractal julia -0.7 +0.27015 j --size=500x300 --depth=512 --zoom=0.6 --show --output=output.png
#images/julia_-0.7+0.27015j_size=500x300_depth=512_zoom=0.6.png
#Julia fractal

display(Image('output.png'))

# !python -m fractal julia -0.7102 +0.2698 j --size=500x300 --depth=512 --zoom=0.65 --show --output=output.png
#images/julia_-0.7102+0.2698j_size=500x300_depth=512_zoom=0.65.png
#Julia fractal

display(Image('output.png'))

# !python -m fractal julia -0.77777 -0.25 j --size=527x331 --depth=200 --zoom=0.7 --show --output=output.png
#images/julia_-0.77777-0.25j_size=527x331_depth=200_zoom=0.7.png
#Julia fractal

display(Image('output.png'))

# !python -m fractal julia -0.8 +0.156 j --size=400x230 --depth=50 --zoom=0.65 --show --output=output.png
#images/julia_-0.8+0.156j_size=400x230_depth=50_zoom=0.65.png
#Julia fractal

# !python -m fractal julia -0.8 +0.156 j --size=500x300 --depth=512 --zoom=0.6 --show --output=output.png
#images/julia_-0.8+0.156j_size=500x300_depth=512_zoom=0.6.png
#Julia fractal

display(Image('output.png'))

# !python -m fractal julia -1.037 +0.17 j --size=600x300 --depth=40 --zoom=0.55 --show --output=output.png
#images/julia_-1.037+0.17j_size=600x300_depth=40_zoom=0.55.png
#Mandelbrot fractal

display(Image('output.png'))

# !python -m fractal mandelbrot --size=300x300 --depth=80 --zoom=1.2 --center=-1x0 --show --output=output.png
#images/mandelbrot_size=300x300_depth=80_zoom=1.2_center=-1x0.png
#Mandelbrot fractal

display(Image('output.png'))

# !python -m fractal mandelbrot --size=400x300 --depth=80 --zoom=2 --center=-1x0 --show --output=output.png
#images/mandelbrot_size=400x300_depth=80_zoom=2_center=-1x0.png
#Mandelbrot fractal

display(Image('output.png'))

# !python -m fractal mandelbrot --size=500x500 --depth=256 --zoom=6.5 --center=-1.2x0.35 --show --output=output.png
#images/mandelbrot_size=500x500_depth=256_zoom=6.5_center=-1.2x0.35.png
#Mandelbrot fractal

display(Image('output.png'))

# !python -m fractal mandelbrot --size=500x500 --depth=80 --zoom=0.8 --center=-0.75x0 --show --output=output.png
#images/mandelbrot_size=500x500_depth=80_zoom=0.8_center=-0.75x0.png
#Mandelbrot fractal

# !python -m fractal mandelbrot --size=600x600 --depth=256 --zoom=90 --center=-1.255x0.38 --show --output=output.png

display(Image('output.png'))
# Out:
# /content
# Cloning into 'fractal'...
# remote: Enumerating objects: 152, done.
# remote: Total 152 (delta 0), reused 0 (delta 0), pack-reused 152
# Receiving objects: 100% (152/152), 1.74 MiB | 4.70 MiB/s, done.
# Resolving deltas: 100% (78/78), done.
# /content/fractal
# CPU Count: 2
# Time taken: 0.7355866432189941
# <Figure size 640x480 with 1 Axes>
# CPU Count: 2
# Time taken: 7.879189968109131
# <Figure size 640x480 with 1 Axes>
# CPU Count: 2
# Time taken: 4.837208986282349
# <Figure size 640x480 with 1 Axes>
# CPU Count: 2
# Time taken: 2.0358030796051025
# <Figure size 640x480 with 1 Axes>
# CPU Count: 2
# Time taken: 1.5639064311981201
# <Figure size 640x480 with 1 Axes>
# CPU Count: 2
# Time taken: 4.942966938018799
# <Figure size 640x480 with 1 Axes>
# CPU Count: 2
# Time taken: 2.1648805141448975
# <Figure size 640x480 with 1 Axes>
# CPU Count: 2
# Time taken: 2.472039222717285
# <Figure size 640x480 with 1 Axes>
# CPU Count: 2
# Time taken: 4.922022581100464
# ...
