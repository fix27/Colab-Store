# %% [markdown]
# <a href="https://colab.research.google.com/github/fix27/Colab-Store/blob/main/html_links.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mechanize
import requests
import subprocess
from mechanize import Browser
file = open('/content/text.txt', "r")#Открываем файл

error=0

line = file.readlines()#список из слов в строчке
br = Browser()
for i in line:
  if len(i)>3 : 
   i=i.rstrip("\n")
   try:
    br.open(i)
    print ("<a href='"+i+"'>"+br.title()+"</a>")
   except: 
    print ("<a href='"+i+"'>"+i+"</a>") 
    error=error+1
# Out:
# ...
# <a href='http://agrodronegroup.ru'>Группа компаний АгроДронГрупп</a>
# <a href='http://ant-company.ru'>http://ant-company.ru</a>
# <a href='http://atlas-aero.ru'>"Атлас-Аэро" - производство беспилотных авиационных систем (БПЛА)</a>
# <a href='http://biometric.bmstu.ru'>http://biometric.bmstu.ru</a>
# <a href='http://biotechsk.com'>http://biotechsk.com</a>
# <a href='http://ckb-rubin.ru'>ЦКБ МТ Рубин: Главная</a>
# <a href='http://cniitm.ru'>http://cniitm.ru</a>
# <a href='http://copterzone.ru'>Срок регистрации домена copterzone.ru истёк</a>
# <a href='http://demorobot.ru'>http://demorobot.ru</a>
# <a href='http://dereviaka.ru'>Деревяка - национальный робот с русской душой</a>
# <a href='http://dknevesomost.ru'>ДК Невесомость</a>
# <a href='http://ekzar34.ru'>Фонд поддержки инновационной медицины «Планета Экзар»</a>
# <a href='http://ev-tech.me'>Беспилотная техника</a>
# <a href='http://examen-technolab.ru'>Экзамен-Технолаб</a>
# ...
