# %% [markdown]
# <a href="https://colab.research.google.com/github/fix27/Colab-Store/blob/main/MasseyRamanujan3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ShaharGottlieb/MasseyRamanujan.git
# %cd MasseyRamanujan
# !pip install -e .
# Out:
# Cloning into 'MasseyRamanujan'...
# remote: Enumerating objects: 1124, done.
# remote: Total 1124 (delta 0), reused 0 (delta 0), pack-reused 1124
# Receiving objects: 100% (1124/1124), 1005.05 KiB | 6.84 MiB/s, done.
# Resolving deltas: 100% (713/713), done.
# /content/MasseyRamanujan/MasseyRamanujan/MasseyRamanujan
# Obtaining file:///content/MasseyRamanujan/MasseyRamanujan/MasseyRamanujan
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.3.1)
# Requirement already satisfied: matplotlib>=3.2.0 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (3.2.2)
# Requirement already satisfied: mpmath>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.1.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.19.5)
# Requirement already satisfied: ordered-set>=3.1.1 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (4.0.2)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.1.5)
# Requirement already satisfied: protobuf>=3.11.3 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (3.12.4)
# Requirement already satisfied: PyLaTeX>=1.3.1 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.4.1)
# Requirement already satisfied: pyparsing>=2.4.6 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (2.8.1)
# Requirement already satisfied: pytz>=2019.3 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (2021.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.15.0)
# Requirement already satisfied: sympy>=1.5.1 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.7.1)
# Requirement already satisfied: ortools>=7.4.7247 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (8.1.8487)
# Requirement already satisfied: pybloom-live in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (3.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.11.3->ramanujan==0.0.1) (53.0.0)
# Requirement already satisfied: absl-py>=0.11 in /usr/local/lib/python3.6/dist-packages (from ortools>=7.4.7247->ramanujan==0.0.1) (0.11.0)
# Requirement already satisfied: bitarray>=0.3.4 in /usr/local/lib/python3.6/dist-packages (from pybloom-live->ramanujan==0.0.1) (1.6.3)
# Installing collected packages: ramanujan
#   Found existing installation: ramanujan 0.0.1
#     Can't uninstall 'ramanujan'. No files were found to uninstall.
#   Running setup.py develop for ramanujan
# Successfully installed ramanujan

# %%
 from ramanujan.LHSHashTable import LHSHashTable
 from ramanujan.constants import g_const_dict

 saved_hash = 'e_lhs_dept5'
 lhs_coefs_range = 20
 lhs = LHSHashTable(
    saved_hash,
    lhs_coefs_range,
    [g_const_dict['e']])
# Out:
# no existing db found, generating dict
# initializing LHS dict: 30.673460245132446

# %%
from ramanujan.poly_domains.CartesianProductPolyDomain import CartesianProductPolyDomain
 
poly_search_domain = CartesianProductPolyDomain(
   1, [-8,8], # an coefs
   2, [-8,8]) # bn coef

# %%
from ramanujan.enumerators.EfficientGCFEnumerator import EfficientGCFEnumerator

enumerator = EfficientGCFEnumerator(
    lhs,
    poly_search_domain,
    [g_const_dict['e']]
    )
results = enumerator.full_execution()
# Out:
# starting preliminary search...
# created final enumerations filters after 0.0014736652374267578s
# passed 100000 out of 569908 (17.55%). found so far 300 results
# passed 200000 out of 569908 (35.09%). found so far 555 results
# passed 300000 out of 569908 (52.64%). found so far 831 results
# passed 400000 out of 569908 (70.19%). found so far 1066 results
# passed 500000 out of 569908 (87.73%). found so far 1307 results
# created results after 20.77632164955139s
# that took 20.780062198638916s
# starting to verify results...
# passed 50 permutations out of 1513. found so far 0 matches
# passed 100 permutations out of 1513. found so far 0 matches
# passed 150 permutations out of 1513. found so far 0 matches
# passed 200 permutations out of 1513. found so far 0 matches
# passed 250 permutations out of 1513. found so far 0 matches
# passed 300 permutations out of 1513. found so far 0 matches
# passed 350 permutations out of 1513. found so far 0 matches
# passed 400 permutations out of 1513. found so far 0 matches
# passed 450 permutations out of 1513. found so far 0 matches
# passed 500 permutations out of 1513. found so far 0 matches
# passed 550 permutations out of 1513. found so far 0 matches
# passed 600 permutations out of 1513. found so far 0 matches
# passed 650 permutations out of 1513. found so far 0 matches
# passed 700 permutations out of 1513. found so far 0 matches
# passed 750 permutations out of 1513. found so far 1 matches
# passed 800 permutations out of 1513. found so far 33 matches
# passed 850 permutations out of 1513. found so far 43 matches
# passed 900 permutations out of 1513. found so far 43 matches
# passed 950 permutations out of 1513. found so far 43 matches
# passed 1000 permutations out of 1513. found so far 43 matches
# passed 1050 permutations out of 1513. found so far 43 matches
# passed 1100 permutations out of 1513. found so far 43 matches
# passed 1150 permutations out of 1513. found so far 43 matches
# passed 1200 permutations out of 1513. found so far 43 matches
# passed 1250 permutations out of 1513. found so far 43 matches
# passed 1300 permutations out of 1513. found so far 43 matches
# passed 1350 permutations out of 1513. found so far 43 matches
# passed 1400 permutations out of 1513. found so far 43 matches
# passed 1450 permutations out of 1513. found so far 43 matches
# passed 1500 permutations out of 1513. found so far 43 matches
# that took 0.18838047981262207s
# -8 + 4⋅ℯ                 12
# ──────── = 8 - ──────────────────────
# -5 + 2⋅ℯ                    16
#                10 - ─────────────────
#                               20
#                     12 - ────────────
#                                  24
#                          14 - ───────
#                                    28
#                               16 - ──
#                                    ..
# (a(n) = 2⋅n + 8, b(n) = -4⋅n - 8)
#
# Converged with a rate of 2.158 digits per term
# -2 + 2⋅ℯ                 8
# ──────── = 6 - ─────────────────────
#  -2 + ℯ                    12
#                8 - ─────────────────
#                              16
#                    10 - ────────────
#                                 20
#                         12 - ───────
#                                   24
#                              14 - ──
#                                   ..
# (a(n) = 2⋅n + 6, b(n) = -4⋅n - 4)
#
# Converged with a rate of 2.1551 digits per term
#   2                   8
# ───── = 8 - ──────────────────────
# 3 - ℯ                    12
#             10 - ─────────────────
#                            16
#                  12 - ────────────
#                               20
#                       14 - ───────
#                                 24
#                            16 - ──
#                                 ..
# (a(n) = 2⋅n + 8, b(n) = -4⋅n - 4)
#
# Converged with a rate of 2.161 digits per term
#  2⋅ℯ                  4
# ────── = 4 - ────────────────────
# -1 + ℯ                  8
#              6 - ────────────────
#                           12
#                  8 - ────────────
#                              16
#                      10 - ───────
#                                20
#                           12 - ──
#                                ..
# (a(n) = 2⋅n + 4, b(n) = -4⋅n)
#
# Converged with a rate of 2.1522 digits per term
#                     4
# 2⋅ℯ = 6 - ─────────────────────
#                       8
#           8 - ─────────────────
#                         12
#               10 - ────────────
#                            16
#                    12 - ───────
#                              20
#                         14 - ──
#                              ..
# (a(n) = 2⋅n + 6, b(n) = -4⋅n)
#
# Converged with a rate of 2.1581 digits per term
#  2⋅ℯ                   4
# ────── = 8 - ──────────────────────
# -2 + ℯ                    8
#              10 - ─────────────────
#                             12
#                   12 - ────────────
#                                16
#                        14 - ───────
#                                  20
#                             16 - ──
#                                  ..
# (a(n) = 2⋅n + 8, b(n) = -4⋅n)
#
# Converged with a rate of 2.164 digits per term
# -15 + 6⋅ℯ               4
# ───────── = 5 - ──────────────────
# -16 + 6⋅ℯ                 5
#                 6 - ──────────────
#                             6
#                     7 - ──────────
#                               7
#                         8 - ──────
#                                 8
#                             9 - ──
#                                 ..
# (a(n) = n + 5, b(n) = -n - 3)
#
# Converged with a rate of 2.1609 digits per term
# -4 + 2⋅ℯ               3
# ──────── = 4 - ──────────────────
# -5 + 2⋅ℯ                 4
#                5 - ──────────────
#                            5
#                    6 - ──────────
#                              6
#                        7 - ──────
#                                7
#                            8 - ──
#                                ..
# (a(n) = n + 4, b(n) = -n - 2)
#
# Converged with a rate of 2.158 digits per term
# 6 - 2⋅ℯ                3
# ──────── = 5 - ──────────────────
# 11 - 4⋅ℯ                 4
#                6 - ──────────────
#                            5
#                    7 - ──────────
#                              6
#                        8 - ──────
#                                7
#                            9 - ──
#                                ..
# (a(n) = n + 5, b(n) = -n - 2)
#
# Converged with a rate of 2.1639 digits per term
#  -8 + 3⋅ℯ                3
# ───────── = 6 - ───────────────────
# -19 + 7⋅ℯ                  4
#                 7 - ───────────────
#                              5
#                     8 - ───────────
#                                6
#                         9 - ───────
#                                  7
#                             10 - ──
#                                  ..
# (a(n) = n + 6, b(n) = -n - 2)
#
# Converged with a rate of 2.1696 digits per term
# -1 + ℯ               2
# ────── = 3 - ──────────────────
# -2 + ℯ                 3
#              4 - ──────────────
#                          4
#                  5 - ──────────
#                            5
#                      6 - ──────
#                              6
#                          7 - ──
#                              ..
# (a(n) = n + 3, b(n) = -n - 1)
#
# Converged with a rate of 2.1551 digits per term
#   1                 2
# ───── = 4 - ──────────────────
# 3 - ℯ                 3
#             5 - ──────────────
#                         4
#                 6 - ──────────
#                           5
#                     7 - ──────
#                             6
#                         8 - ──
#                             ..
# (a(n) = n + 4, b(n) = -n - 1)
#
# Converged with a rate of 2.161 digits per term
#  -2 + ℯ                2
# ──────── = 5 - ──────────────────
# -8 + 3⋅ℯ                 3
#                6 - ──────────────
#                            4
#                    7 - ──────────
#                              5
#                        8 - ──────
#                                6
#                            9 - ──
#                                ..
# (a(n) = n + 5, b(n) = -n - 1)
#
# Converged with a rate of 2.1668 digits per term
#   ℯ                  1
# ────── = 2 - ──────────────────
# -1 + ℯ                 2
#              3 - ──────────────
#                          3
#                  4 - ──────────
#                            4
#                      5 - ──────
#                              5
#                          6 - ──
#                              ..
# (a(n) = n + 2, b(n) = -n)
#
# Converged with a rate of 2.1522 digits per term
#                 1
# ℯ = 3 - ──────────────────
#                   2
#         4 - ──────────────
#                     3
#             5 - ──────────
#                       4
#                 6 - ──────
#                         5
#                     7 - ──
#                         ..
# (a(n) = n + 3, b(n) = -n)
#
# Converged with a rate of 2.1581 digits per term
#   ℯ                  1
# ────── = 4 - ──────────────────
# -2 + ℯ                 2
#              5 - ──────────────
#                          3
#                  6 - ──────────
#                            4
#                      7 - ──────
#                              5
#                          8 - ──
#                              ..
# (a(n) = n + 4, b(n) = -n)
#
# Converged with a rate of 2.164 digits per term
#    ℯ                  1
# ─────── = 5 - ──────────────────
# 6 - 2⋅ℯ                 2
#               6 - ──────────────
#                           3
#                   7 - ──────────
#                             4
#                       8 - ──────
#                               5
#                           9 - ──
#                               ..
# (a(n) = n + 5, b(n) = -n)
#
# Converged with a rate of 2.1698 digits per term
# 19 + 7⋅ℯ                 1
# ──────── = -6 + ────────────────────
#  -3 - ℯ                     1
#                 -2 + ───────────────
#                               1
#                      2 + ───────────
#                                 1
#                          6 + ───────
#                                   1
#                              10 + ──
#                                   ..
# (a(n) = 4⋅n - 6, b(n) = 1)
#
# Converged with a rate of 5.4786 digits per term
# ℯ + 3                  1
# ────── = -2 + ────────────────────
# -ℯ - 1                   1
#               2 + ────────────────
#                            1
#                   6 + ────────────
#                               1
#                       10 + ───────
#                                 1
#                            14 + ──
#                                 ..
# (a(n) = 4⋅n - 2, b(n) = 1)
#
# Converged with a rate of 5.4846 digits per term
# 1 + ℯ                  1
# ────── = 2 + ─────────────────────
# -1 + ℯ                   1
#              6 + ─────────────────
#                            1
#                  10 + ────────────
#                               1
#                       14 + ───────
#                                 1
#                            18 + ──
#                                 ..
# (a(n) = 4⋅n + 2, b(n) = 1)
#
# Converged with a rate of 5.4905 digits per term
# -1 + ℯ                 1
# ────── = 6 + ──────────────────────
# 3 - ℯ                     1
#              10 + ─────────────────
#                             1
#                   14 + ────────────
#                                1
#                        18 + ───────
#                                  1
#                             22 + ──
#                                  ..
# (a(n) = 4⋅n + 6, b(n) = 1)
#
# Converged with a rate of 5.4964 digits per term
# 2⋅ℯ + 6                  4
# ─────── = -4 + ─────────────────────
#  -ℯ - 1                    4
#                4 + ─────────────────
#                              4
#                    12 + ────────────
#                                 4
#                         20 + ───────
#                                   4
#                              28 + ──
#                                   ..
# (a(n) = 8⋅n - 4, b(n) = 4)
#
# Converged with a rate of 5.4846 digits per term
# 2 + 2⋅ℯ                 4
# ─────── = 4 + ──────────────────────
#  -1 + ℯ                    4
#               12 + ─────────────────
#                              4
#                    20 + ────────────
#                                 4
#                         28 + ───────
#                                   4
#                              36 + ──
#                                   ..
# (a(n) = 8⋅n + 4, b(n) = 4)
#
# Converged with a rate of 5.4905 digits per term
#   1              1
# ────── = ──────────────────
# -1 + ℯ             2
#          1 + ──────────────
#                      3
#              2 + ──────────
#                        4
#                  3 + ──────
#                          5
#                      4 + ──
#                          ..
# (a(n) = n, b(n) = n)
#
# Converged with a rate of 2.1522 digits per term
#   1                  1
# ────── = 1 + ──────────────────
# -2 + ℯ                 2
#              2 + ──────────────
#                          3
#                  3 + ──────────
#                            4
#                      4 + ──────
#                              5
#                          5 + ──
#                              ..
# (a(n) = n + 1, b(n) = n)
#
# Converged with a rate of 2.158 digits per term
#    1                   1
# ──────── = 2 + ──────────────────
# -5 + 2⋅ℯ                 2
#                3 + ──────────────
#                            3
#                    4 + ──────────
#                              4
#                        5 + ──────
#                                5
#                            6 + ──
#                                ..
# (a(n) = n + 2, b(n) = n)
#
# Converged with a rate of 2.1638 digits per term
#     1                   1
# ───────── = 3 + ──────────────────
# -16 + 6⋅ℯ                 2
#                 4 + ──────────────
#                             3
#                     5 + ──────────
#                               4
#                         6 + ──────
#                                 5
#                             7 + ──
#                                 ..
# (a(n) = n + 3, b(n) = n)
#
# Converged with a rate of 2.1695 digits per term
#                      2
# -1 + ℯ = 1 + ──────────────────
#                        3
#              2 + ──────────────
#                          4
#                  3 + ──────────
#                            5
#                      4 + ──────
#                              6
#                          5 + ──
#                              ..
# (a(n) = n + 1, b(n) = n + 1)
#
# Converged with a rate of 2.1551 digits per term
# -2 + ℯ               2
# ────── = 2 + ──────────────────
# 3 - ℯ                  3
#              3 + ──────────────
#                          4
#                  4 + ──────────
#                            5
#                      5 + ──────
#                              6
#                          6 + ──
#                              ..
# (a(n) = n + 2, b(n) = n + 1)
#
# Converged with a rate of 2.1609 digits per term
# -5 + 2⋅ℯ               2
# ──────── = 3 + ──────────────────
# 11 - 4⋅ℯ                 3
#                4 + ──────────────
#                            4
#                    5 + ──────────
#                              5
#                        6 + ──────
#                                6
#                            7 + ──
#                                ..
# (a(n) = n + 3, b(n) = n + 1)
#
# Converged with a rate of 2.1666 digits per term
#   2                  3
# ────── = 2 + ──────────────────
# -2 + ℯ                 4
#              3 + ──────────────
#                          5
#                  4 + ──────────
#                            6
#                      5 + ──────
#                              7
#                          6 + ──
#                              ..
# (a(n) = n + 2, b(n) = n + 2)
#
# Converged with a rate of 2.158 digits per term
# 6 - 2⋅ℯ                3
# ──────── = 3 + ──────────────────
# -8 + 3⋅ℯ                 4
#                4 + ──────────────
#                            5
#                    5 + ──────────
#                              6
#                        6 + ──────
#                                7
#                            7 + ──
#                                ..
# (a(n) = n + 3, b(n) = n + 2)
#
# Converged with a rate of 2.1637 digits per term
#  11 - 4⋅ℯ               3
# ───────── = 4 + ──────────────────
# -19 + 7⋅ℯ                 4
#                 5 + ──────────────
#                             5
#                     6 + ──────────
#                               6
#                         7 + ──────
#                                 7
#                             8 + ──
#                                 ..
# (a(n) = n + 4, b(n) = n + 2)
#
# Converged with a rate of 2.1694 digits per term
# -6 + 3⋅ℯ               4
# ──────── = 3 + ──────────────────
# 6 - 2⋅ℯ                  5
#                4 + ──────────────
#                            6
#                    5 + ──────────
#                              7
#                        6 + ──────
#                                8
#                            7 + ──
#                                ..
# (a(n) = n + 3, b(n) = n + 3)
#
# Converged with a rate of 2.1609 digits per term
#   2              4
# ────── = ──────────────────
# -1 + ℯ             8
#          2 + ──────────────
#                      12
#              4 + ──────────
#                        16
#                  6 + ──────
#                          20
#                      8 + ──
#                          ..
# (a(n) = 2⋅n, b(n) = 4⋅n)
#
# Converged with a rate of 2.1522 digits per term
#   2                   4
# ────── = 2 + ───────────────────
# -2 + ℯ                  8
#              4 + ───────────────
#                           12
#                  6 + ───────────
#                             16
#                      8 + ───────
#                               20
#                          10 + ──
#                               ..
# (a(n) = 2⋅n + 2, b(n) = 4⋅n)
#
# Converged with a rate of 2.158 digits per term
#    2                    4
# ──────── = 4 + ────────────────────
# -5 + 2⋅ℯ                  8
#                6 + ────────────────
#                             12
#                    8 + ────────────
#                                16
#                        10 + ───────
#                                  20
#                             12 + ──
#                                  ..
# (a(n) = 2⋅n + 4, b(n) = 4⋅n)
#
# Converged with a rate of 2.1638 digits per term
#    1                     4
# ──────── = 6 + ─────────────────────
# -8 + 3⋅ℯ                   8
#                8 + ─────────────────
#                              12
#                    10 + ────────────
#                                 16
#                         12 + ───────
#                                   20
#                              14 + ──
#                                   ..
# (a(n) = 2⋅n + 6, b(n) = 4⋅n)
#
# Converged with a rate of 2.1695 digits per term
#                         8
# -2 + 2⋅ℯ = 2 + ───────────────────
#                           12
#                4 + ───────────────
#                             16
#                    6 + ───────────
#                               20
#                        8 + ───────
#                                 24
#                            10 + ──
#                                 ..
# (a(n) = 2⋅n + 2, b(n) = 4⋅n + 4)
#
# Converged with a rate of 2.1551 digits per term
# -4 + 2⋅ℯ                8
# ──────── = 4 + ────────────────────
#  3 - ℯ                    12
#                6 + ────────────────
#                             16
#                    8 + ────────────
#                                20
#                        10 + ───────
#                                  24
#                             12 + ──
#                                  ..
# (a(n) = 2⋅n + 4, b(n) = 4⋅n + 4)
#
# Converged with a rate of 2.1609 digits per term
# -10 + 4⋅ℯ                 8
# ───────── = 6 + ─────────────────────
#  11 - 4⋅ℯ                   12
#                 8 + ─────────────────
#                               16
#                     10 + ────────────
#                                  20
#                          12 + ───────
#                                    24
#                               14 + ──
#                                    ..
# (a(n) = 2⋅n + 6, b(n) = 4⋅n + 4)
#
# Converged with a rate of 2.1666 digits per term
#   4                   12
# ────── = 4 + ────────────────────
# -2 + ℯ                  16
#              6 + ────────────────
#                           20
#                  8 + ────────────
#                              24
#                      10 + ───────
#                                28
#                           12 + ──
#                                ..
# (a(n) = 2⋅n + 4, b(n) = 4⋅n + 8)
#
# Converged with a rate of 2.158 digits per term
# 12 - 4⋅ℯ                 12
# ──────── = 6 + ─────────────────────
# -8 + 3⋅ℯ                   16
#                8 + ─────────────────
#                              20
#                    10 + ────────────
#                                 24
#                         12 + ───────
#                                   28
#                              14 + ──
#                                   ..
# (a(n) = 2⋅n + 6, b(n) = 4⋅n + 8)
#
# Converged with a rate of 2.1637 digits per term
