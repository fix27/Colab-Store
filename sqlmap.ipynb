# %% [markdown]
# <a href="https://colab.research.google.com/github/fix27/Colab-Store/blob/main/sqlmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone --depth 1 https://github.com/sqlmapproject/sqlmap.git sqlmap-dev
# Out:
# Cloning into 'sqlmap-dev'...
# remote: Enumerating objects: 689, done.
# remote: Counting objects: 100% (689/689), done.
# remote: Compressing objects: 100% (623/623), done.
# remote: Total 689 (delta 212), reused 216 (delta 55), pack-reused 0
# Receiving objects: 100% (689/689), 6.55 MiB | 5.72 MiB/s, done.
# Resolving deltas: 100% (212/212), done.

# %%
# !python ./sqlmap-dev/sqlmap.py -u https://insideevs.ru/ --batch --crawl=3
# Out:
#         ___
#        __H__
#  ___ ___["]_____ ___ ___  {1.4.6.2#dev}
# |_ -| . [.]     | .'| . |
# |___|_  [)]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 11:37:48 /2020-06-06/
#
# do you want to check for the existence of site's sitemap(.xml) [y/N] N
# [11:37:48] [INFO] starting crawler for target URL 'https://insideevs.ru/'
# [11:37:48] [INFO] searching for links with depth 1
# [11:37:51] [INFO] searching for links with depth 2
# please enter number of threads? [Enter for 1 (current)] 1
# [11:37:51] [WARNING] running in a single-thread mode. This could take a while
# [11:38:02] [INFO] 5/52 links visited (10%)
# ...
