# %% [markdown]
# <a href="https://colab.research.google.com/github/fix27/Colab-Store/blob/main/MasseyRamanujan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ShaharGottlieb/MasseyRamanujan.git
# %cd MasseyRamanujan
# !pip install -e .
# Out:
# Cloning into 'MasseyRamanujan'...
# remote: Enumerating objects: 1124, done.
# remote: Total 1124 (delta 0), reused 0 (delta 0), pack-reused 1124
# Receiving objects: 100% (1124/1124), 1005.05 KiB | 7.08 MiB/s, done.
# Resolving deltas: 100% (713/713), done.
# /content/MasseyRamanujan
# Obtaining file:///content/MasseyRamanujan
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.3.1)
# Requirement already satisfied: matplotlib>=3.2.0 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (3.2.2)
# Requirement already satisfied: mpmath>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.1.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.19.5)
# Collecting ordered-set>=3.1.1
#   Downloading https://files.pythonhosted.org/packages/f5/ab/8252360bfe965bba31ec05112b3067bd129ce4800d89e0b85613bc6044f6/ordered-set-4.0.2.tar.gz
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.1.5)
# Requirement already satisfied: protobuf>=3.11.3 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (3.12.4)
# Collecting PyLaTeX>=1.3.1
#   Downloading https://files.pythonhosted.org/packages/8a/76/015a1d785221d9b0d2ad80759d892a6d9d0a8a05daffc52202311ea3d652/PyLaTeX-1.4.1.tar.gz (84kB)
#      |████████████████████████████████| 92kB 4.2MB/s
# Requirement already satisfied: pyparsing>=2.4.6 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (2.8.1)
# Collecting pytz>=2019.3
#   Downloading https://files.pythonhosted.org/packages/70/94/784178ca5dd892a98f113cdd923372024dc04b8d40abe77ca76b5fb90ca6/pytz-2021.1-py2.py3-none-any.whl (510kB)
#      |████████████████████████████████| 512kB 7.7MB/s
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from ramanujan==0.0.1) (1.15.0)
# Collecting sympy>=1.5.1
#   Downloading https://files.pythonhosted.org/packages/ff/69/b16fc81b939d3efdd0b552f2e3e54f7fa1423d0c320cced2e69e675dde26/sympy-1.7.1-py3-none-any.whl (5.9MB)
#      |████████████████████████████████| 5.9MB 9.6MB/s
# Collecting ortools>=7.4.7247
#   Downloading https://files.pythonhosted.org/packages/63/94/2832edee6f4fb4e77e8585b6034f9506be24361fe6ead4e76de38ab0a666/ortools-8.1.8487-cp36-cp36m-manylinux1_x86_64.whl (14.0MB)
#      |████████████████████████████████| 14.0MB 325kB/s
# Collecting pybloom-live
#   Downloading https://files.pythonhosted.org/packages/ea/43/93b606bc267ab48da54b3adcc18c4521ed2526312c7dd37958dde36bb7cc/pybloom_live-3.0.0.tar.gz
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.11.3->ramanujan==0.0.1) (53.0.0)
# Collecting absl-py>=0.11
#   Downloading https://files.pythonhosted.org/packages/bc/58/0aa6fb779dc69cfc811df3398fcbeaeefbf18561b6e36b185df0782781cc/absl_py-0.11.0-py3-none-any.whl (127kB)
#      |████████████████████████████████| 133kB 40.6MB/s
# Collecting bitarray>=0.3.4
#   Downloading https://files.pythonhosted.org/packages/eb/98/7ed097e25cfbfda00ba59fe567d1c98c4241fb4925fc8cbf7106a5449bdf/bitarray-1.6.3.tar.gz (57kB)
#      |████████████████████████████████| 61kB 5.2MB/s
# Building wheels for collected packages: ordered-set, PyLaTeX, pybloom-live, bitarray
#   Building wheel for ordered-set (setup.py) ... done
#   Created wheel for ordered-set: filename=ordered_set-4.0.2-py2.py3-none-any.whl size=8210 sha256=20c23858770c1c265a8325d825a9239346d77547cd4fc67332987e3761ecddff
#   Stored in directory: /root/.cache/pip/wheels/e1/c6/9b/651d8a21d59b51a75ab9c070838f9231b8126421bc0569af47
#   Building wheel for PyLaTeX (setup.py) ... done
#   Created wheel for PyLaTeX: filename=PyLaTeX-1.4.1-cp36-none-any.whl size=42815 sha256=30e4f6467328c7b879b3eabc22cda62ab6f73450fd2a58ce40211bcc0e5ad2bb
#   Stored in directory: /root/.cache/pip/wheels/a2/25/3a/2cc0a6219d95ce34f1f7439a6427c62ca262ebaeb5969db89f
#   Building wheel for pybloom-live (setup.py) ... done
#   Created wheel for pybloom-live: filename=pybloom_live-3.0.0-cp36-none-any.whl size=8345 sha256=10ca0c26339578b90bdaf5191a3d4af6f99f77c5d6fbf4e719d2f2d7d884da39
#   Stored in directory: /root/.cache/pip/wheels/46/82/30/29f1691f49ac0d4ea9706f58cada5e3bbfe5558b09dbdbc8c5
#   Building wheel for bitarray (setup.py) ... done
#   Created wheel for bitarray: filename=bitarray-1.6.3-cp36-cp36m-linux_x86_64.whl size=118968 sha256=ebba1352064890f6ad8622338d4b03704a3b0e800d23f23e54c1a375a92fe005
#   Stored in directory: /root/.cache/pip/wheels/13/24/95/e465c81652208d64cc3e7c3556a3a5b1d605f8637c8eda8a69
# Successfully built ordered-set PyLaTeX pybloom-live bitarray
# ERROR: tensorflow-metadata 0.27.0 has requirement absl-py<0.11,>=0.9, but you'll have absl-py 0.11.0 which is incompatible.
# ERROR: ortools 8.1.8487 has requirement protobuf>=3.14.0, but you'll have protobuf 3.12.4 which is incompatible.
# Installing collected packages: ordered-set, PyLaTeX, pytz, sympy, absl-py, ortools, bitarray, pybloom-live, ramanujan
#   Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Found existing installation: sympy 1.1.1
#     Uninstalling sympy-1.1.1:
#       Successfully uninstalled sympy-1.1.1
#   Found existing installation: absl-py 0.10.0
#     Uninstalling absl-py-0.10.0:
#       Successfully uninstalled absl-py-0.10.0
#   Running setup.py develop for ramanujan
# Successfully installed PyLaTeX-1.4.1 absl-py-0.11.0 bitarray-1.6.3 ordered-set-4.0.2 ortools-8.1.8487 pybloom-live-3.0.0 pytz-2021.1 ramanujan sympy-1.7.1

# %%
 from ramanujan.LHSHashTable import LHSHashTable
 from ramanujan.constants import g_const_dict

 saved_hash = 'e_lhs_dept5'
 lhs_coefs_range = 14
 lhs = LHSHashTable(
    saved_hash,
    lhs_coefs_range,
    [g_const_dict['e']])
# Out:
# no existing db found, generating dict
# initializing LHS dict: 3.7829859256744385

# %%
from ramanujan.poly_domains.CartesianProductPolyDomain import CartesianProductPolyDomain
 
poly_search_domain = CartesianProductPolyDomain(
   1, [-5, 5], # an coefs
   1, [-5, 5]) # bn coef

# %%
from ramanujan.enumerators.EfficientGCFEnumerator import EfficientGCFEnumerator

enumerator = EfficientGCFEnumerator(
    lhs,
    poly_search_domain,
    [g_const_dict['e']]
    )
results = enumerator.full_execution()
# Out:
# starting preliminary search...
# created final enumerations filters after 0.0005235671997070312s
# created results after 0.18345856666564941s
# that took 0.18417048454284668s
# starting to verify results...
# that took 0.08133244514465332s
#  2⋅ℯ                  4
# ────── = 4 - ────────────────────
# -1 + ℯ                  8
#              6 - ────────────────
#                           12
#                  8 - ────────────
#                              16
#                      10 - ───────
#                                20
#                           12 - ──
#                                ..
# (a(n) = 2⋅n + 4, b(n) = -4⋅n)
#
# Converged with a rate of 2.1522 digits per term
# -4 + 2⋅ℯ               3
# ──────── = 4 - ──────────────────
# -5 + 2⋅ℯ                 4
#                5 - ──────────────
#                            5
#                    6 - ──────────
#                              6
#                        7 - ──────
#                                7
#                            8 - ──
#                                ..
# (a(n) = n + 4, b(n) = -n - 2)
#
# Converged with a rate of 2.158 digits per term
# 6 - 2⋅ℯ                3
# ──────── = 5 - ──────────────────
# 11 - 4⋅ℯ                 4
#                6 - ──────────────
#                            5
#                    7 - ──────────
#                              6
#                        8 - ──────
#                                7
#                            9 - ──
#                                ..
# (a(n) = n + 5, b(n) = -n - 2)
#
# Converged with a rate of 2.1639 digits per term
# -1 + ℯ               2
# ────── = 3 - ──────────────────
# -2 + ℯ                 3
#              4 - ──────────────
#                          4
#                  5 - ──────────
#                            5
#                      6 - ──────
#                              6
#                          7 - ──
#                              ..
# (a(n) = n + 3, b(n) = -n - 1)
#
# Converged with a rate of 2.1551 digits per term
#   1                 2
# ───── = 4 - ──────────────────
# 3 - ℯ                 3
#             5 - ──────────────
#                         4
#                 6 - ──────────
#                           5
#                     7 - ──────
#                             6
#                         8 - ──
#                             ..
# (a(n) = n + 4, b(n) = -n - 1)
#
# Converged with a rate of 2.161 digits per term
#  -2 + ℯ                2
# ──────── = 5 - ──────────────────
# -8 + 3⋅ℯ                 3
#                6 - ──────────────
#                            4
#                    7 - ──────────
#                              5
#                        8 - ──────
#                                6
#                            9 - ──
#                                ..
# (a(n) = n + 5, b(n) = -n - 1)
#
# Converged with a rate of 2.1668 digits per term
#   ℯ                  1
# ────── = 2 - ──────────────────
# -1 + ℯ                 2
#              3 - ──────────────
#                          3
#                  4 - ──────────
#                            4
#                      5 - ──────
#                              5
#                          6 - ──
#                              ..
# (a(n) = n + 2, b(n) = -n)
#
# Converged with a rate of 2.1522 digits per term
#                 1
# ℯ = 3 - ──────────────────
#                   2
#         4 - ──────────────
#                     3
#             5 - ──────────
#                       4
#                 6 - ──────
#                         5
#                     7 - ──
#                         ..
# (a(n) = n + 3, b(n) = -n)
#
# Converged with a rate of 2.1581 digits per term
#   ℯ                  1
# ────── = 4 - ──────────────────
# -2 + ℯ                 2
#              5 - ──────────────
#                          3
#                  6 - ──────────
#                            4
#                      7 - ──────
#                              5
#                          8 - ──
#                              ..
# (a(n) = n + 4, b(n) = -n)
#
# Converged with a rate of 2.164 digits per term
#    ℯ                  1
# ─────── = 5 - ──────────────────
# 6 - 2⋅ℯ                 2
#               6 - ──────────────
#                           3
#                   7 - ──────────
#                             4
#                       8 - ──────
#                               5
#                           9 - ──
#                               ..
# (a(n) = n + 5, b(n) = -n)
#
# Converged with a rate of 2.1698 digits per term
# ℯ + 3                  1
# ────── = -2 + ────────────────────
# -ℯ - 1                   1
#               2 + ────────────────
#                            1
#                   6 + ────────────
#                               1
#                       10 + ───────
#                                 1
#                            14 + ──
#                                 ..
# (a(n) = 4⋅n - 2, b(n) = 1)
#
# Converged with a rate of 5.4846 digits per term
# 1 + ℯ                  1
# ────── = 2 + ─────────────────────
# -1 + ℯ                   1
#              6 + ─────────────────
#                            1
#                  10 + ────────────
#                               1
#                       14 + ───────
#                                 1
#                            18 + ──
#                                 ..
# (a(n) = 4⋅n + 2, b(n) = 1)
#
# Converged with a rate of 5.4905 digits per term
#   1              1
# ────── = ──────────────────
# -1 + ℯ             2
#          1 + ──────────────
#                      3
#              2 + ──────────
#                        4
#                  3 + ──────
#                          5
#                      4 + ──
#                          ..
# (a(n) = n, b(n) = n)
#
# Converged with a rate of 2.1522 digits per term
#   1                  1
# ────── = 1 + ──────────────────
# -2 + ℯ                 2
#              2 + ──────────────
#                          3
#                  3 + ──────────
#                            4
#                      4 + ──────
#                              5
#                          5 + ──
#                              ..
# (a(n) = n + 1, b(n) = n)
#
# Converged with a rate of 2.158 digits per term
#    1                   1
# ──────── = 2 + ──────────────────
# -5 + 2⋅ℯ                 2
#                3 + ──────────────
#                            3
#                    4 + ──────────
#                              4
#                        5 + ──────
#                                5
#                            6 + ──
#                                ..
# (a(n) = n + 2, b(n) = n)
#
# Converged with a rate of 2.1638 digits per term
#                      2
# -1 + ℯ = 1 + ──────────────────
#                        3
#              2 + ──────────────
#                          4
#                  3 + ──────────
#                            5
#                      4 + ──────
#                              6
#                          5 + ──
#                              ..
# (a(n) = n + 1, b(n) = n + 1)
#
# Converged with a rate of 2.1551 digits per term
# -2 + ℯ               2
# ────── = 2 + ──────────────────
# 3 - ℯ                  3
#              3 + ──────────────
#                          4
#                  4 + ──────────
#                            5
#                      5 + ──────
#                              6
#                          6 + ──
#                              ..
# (a(n) = n + 2, b(n) = n + 1)
#
# Converged with a rate of 2.1609 digits per term
# -5 + 2⋅ℯ               2
# ──────── = 3 + ──────────────────
# 11 - 4⋅ℯ                 3
#                4 + ──────────────
#                            4
#                    5 + ──────────
#                              5
#                        6 + ──────
#                                6
#                            7 + ──
#                                ..
# (a(n) = n + 3, b(n) = n + 1)
#
# Converged with a rate of 2.1666 digits per term
#   2                  3
# ────── = 2 + ──────────────────
# -2 + ℯ                 4
#              3 + ──────────────
#                          5
#                  4 + ──────────
#                            6
#                      5 + ──────
#                              7
#                          6 + ──
#                              ..
# (a(n) = n + 2, b(n) = n + 2)
#
# Converged with a rate of 2.158 digits per term
# 6 - 2⋅ℯ                3
# ──────── = 3 + ──────────────────
# -8 + 3⋅ℯ                 4
#                4 + ──────────────
#                            5
#                    5 + ──────────
#                              6
#                        6 + ──────
#                                7
#                            7 + ──
#                                ..
# (a(n) = n + 3, b(n) = n + 2)
#
# Converged with a rate of 2.1637 digits per term
# -6 + 3⋅ℯ               4
# ──────── = 3 + ──────────────────
# 6 - 2⋅ℯ                  5
#                4 + ──────────────
#                            6
#                    5 + ──────────
#                              7
#                        6 + ──────
#                                8
#                            7 + ──
#                                ..
# (a(n) = n + 3, b(n) = n + 3)
#
# Converged with a rate of 2.1609 digits per term
#   2              4
# ────── = ──────────────────
# -1 + ℯ             8
#          2 + ──────────────
#                      12
#              4 + ──────────
#                        16
#                  6 + ──────
#                          20
#                      8 + ──
#                          ..
# (a(n) = 2⋅n, b(n) = 4⋅n)
#
# Converged with a rate of 2.1522 digits per term
#   2                   4
# ────── = 2 + ───────────────────
# -2 + ℯ                  8
#              4 + ───────────────
#                           12
#                  6 + ───────────
#                             16
#                      8 + ───────
#                               20
#                          10 + ──
#                               ..
# (a(n) = 2⋅n + 2, b(n) = 4⋅n)
#
# Converged with a rate of 2.158 digits per term
#    2                    4
# ──────── = 4 + ────────────────────
# -5 + 2⋅ℯ                  8
#                6 + ────────────────
#                             12
#                    8 + ────────────
#                                16
#                        10 + ───────
#                                  20
#                             12 + ──
#                                  ..
# (a(n) = 2⋅n + 4, b(n) = 4⋅n)
#
# Converged with a rate of 2.1638 digits per term
#                         8
# -2 + 2⋅ℯ = 2 + ───────────────────
#                           12
#                4 + ───────────────
#                             16
#                    6 + ───────────
#                               20
#                        8 + ───────
#                                 24
#                            10 + ──
#                                 ..
# (a(n) = 2⋅n + 2, b(n) = 4⋅n + 4)
#
# Converged with a rate of 2.1551 digits per term
# -4 + 2⋅ℯ                8
# ──────── = 4 + ────────────────────
#  3 - ℯ                    12
#                6 + ────────────────
#                             16
#                    8 + ────────────
#                                20
#                        10 + ───────
#                                  24
#                             12 + ──
#                                  ..
# (a(n) = 2⋅n + 4, b(n) = 4⋅n + 4)
#
# Converged with a rate of 2.1609 digits per term
